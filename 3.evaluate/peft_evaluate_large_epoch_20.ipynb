# %%
# !pip install -q bitsandbytes peft datasets[audio] jiwer
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 68.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 28.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.0 MB/s eta 0:00:00

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
from transformers import (
    AutomaticSpeechRecognitionPipeline,
    WhisperForConditionalGeneration,
    WhisperTokenizer,
    WhisperProcessor,
)
from peft import PeftModel, PeftConfig
import torch
class SpeechRecognizer:
    def __init__(self, peft_model_id, language="malay", task="transcribe"):
        # Store the language and task
        self.language = language
        self.task = task

        # Load PeftConfig
        self.peft_model_id = peft_model_id
        peft_config = PeftConfig.from_pretrained(self.peft_model_id)

        # Load the model, tokenizer, processor, and other necessary components
        self.model = WhisperForConditionalGeneration.from_pretrained(
            peft_config.base_model_name_or_path, load_in_8bit=True, device_map="auto"
        )
        self.model = PeftModel.from_pretrained(self.model, self.peft_model_id)
        self.tokenizer = WhisperTokenizer.from_pretrained(peft_config.base_model_name_or_path, language=self.language, task=self.task)
        self.processor = WhisperProcessor.from_pretrained(peft_config.base_model_name_or_path, language=self.language, task=self.task)
        self.feature_extractor = self.processor.feature_extractor
        self.forced_decoder_ids = self.processor.get_decoder_prompt_ids(language=self.language, task=self.task)

        # Initialize the pipeline for ASR
        self.pipe = AutomaticSpeechRecognitionPipeline(
            model=self.model, tokenizer=self.tokenizer, feature_extractor=self.feature_extractor
        )

    def transcribe(self, audio_file):
        # Perform transcription with automatic mixed precision if CUDA is available
        if torch.cuda.is_available():
            with torch.cuda.amp.autocast():
                result = self.pipe(audio_file, generate_kwargs={"forced_decoder_ids": self.forced_decoder_ids}, max_new_tokens=255)
        else:
            result = self.pipe(audio_file, generate_kwargs={"forced_decoder_ids": self.forced_decoder_ids}, max_new_tokens=255)

        # Return the transcribed text
        return result["text"]

# %%
peft_model_id_1 = "clt013/whisper-large-v3-ft-malay-peft-epoch-20"
perf_model_id_2 = "clt013/whisper-small-ft-malay-peft-epoch-20"
whisper_large_v3_recognizer = SpeechRecognizer(peft_model_id=peft_model_id_1)
# whisper_small_recognizer = SpeechRecognizer(peft_model_id=perf_model_id_2)
# Out:
# adapter_config.json:   0%|          | 0.00/771 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.90k [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/63.0M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]

# %%
# save to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import time
from datasets import load_dataset, concatenate_datasets

def transcribe_and_compare(dataset_name,
                          #  whisper_small_recognizer,
                           whisper_large_v3_recognizer,
                           limit=10, limited=False):
    """
    Transcribe audio samples from the dataset using two different Whisper models, compare the transcriptions,
    and measure the processing time for each transcription.

    Args:
    - dataset_name (str): The name of the dataset to load.
    - whisper_small_recognizer: The recognizer object for the small Whisper model.
    - whisper_large_v3_recognizer: The recognizer object for the large Whisper model.
    - limit (int): The number of samples to process if 'limited' is True.
    - limited (bool): Whether to limit the number of samples processed.

    Returns:
    - df (DataFrame): A pandas DataFrame containing the reference sentence, transcriptions,
                      and processing times for the two Whisper models.
    """
    # Load the dataset
    dataset = load_dataset(dataset_name)

    # Concatenate train and test sets
    concatenated_dataset = concatenate_datasets([dataset["train"], dataset["test"]])

    # Prepare to store the results
    df_list = []

    # Loop through the dataset, limited by the specified amount if necessary
    for i in range(limit if limited else len(concatenated_dataset)):
        audio_sample = concatenated_dataset[i]['audio']
        samples = audio_sample['array']
        reference = concatenated_dataset[i]['sentence']

        # Transcribe using whisper_small_recognizer and measure processing time
        # start_time_small = time.time()
        # transcribed_1 = whisper_small_recognizer.transcribe(audio_sample)
        # end_time_small = time.time()
        # process_time_small = end_time_small - start_time_small

        # Transcribe using whisper_large_v3_recognizer and measure processing time
        start_time_large = time.time()
        # audio_sample = concatenated_dataset[i]['audio']
        transcribed_2 = whisper_large_v3_recognizer.transcribe(audio_sample)
        end_time_large = time.time()
        process_time_large = end_time_large - start_time_large

        # Append the results to the list, including processing times
        df_list.append(pd.DataFrame({
            'reference': [reference],
            # 'whisper_small_prediction': [transcribed_1],
            'whisper_large_v3_prediction': [transcribed_2],
            # 'whisper_small_process_time': [process_time_small],
            'whisper_large_v3_process_time': [process_time_large]
        }))

        print(f"Processed sample {i}: large model time = {process_time_large:.2f}s")

    # Combine the results into a single DataFrame
    df = pd.concat(df_list, ignore_index=True)

    return df

# %%
df_results = transcribe_and_compare("clt013/malay-speech-3k-rows-dataset_v2", whisper_large_v3_recognizer)
df_results
# Out:
# README.md:   0%|          | 0.00/460 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/216M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/59.7M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2544 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/604 [00:00<?, ? examples/s]
# <ipython-input-3-bd40256c27b2>:37: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:316: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Processed sample 0: large model time = 4.77s
# Processed sample 1: large model time = 2.65s
# Processed sample 2: large model time = 2.64s
# Processed sample 3: large model time = 1.15s
# Processed sample 4: large model time = 1.75s
# Processed sample 5: large model time = 2.14s
# Processed sample 6: large model time = 2.51s
# Processed sample 7: large model time = 2.81s
# Processed sample 8: large model time = 2.16s
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Processed sample 9: large model time = 1.27s
# Processed sample 10: large model time = 1.53s
# Processed sample 11: large model time = 1.72s
# Processed sample 12: large model time = 3.30s
# Processed sample 13: large model time = 0.99s
# Processed sample 14: large model time = 0.87s
# Processed sample 15: large model time = 3.67s
# Processed sample 16: large model time = 1.55s
# Processed sample 17: large model time = 0.89s
# Processed sample 18: large model time = 1.53s
# Processed sample 19: large model time = 1.51s
# Processed sample 20: large model time = 4.46s
# Processed sample 21: large model time = 0.93s
# Processed sample 22: large model time = 0.86s
# Processed sample 23: large model time = 1.47s
# Processed sample 24: large model time = 3.03s
# Processed sample 25: large model time = 3.08s
# Processed sample 26: large model time = 3.84s
# Processed sample 27: large model time = 2.62s
# Processed sample 28: large model time = 1.34s
# Processed sample 29: large model time = 4.30s
# Processed sample 30: large model time = 1.71s
# Processed sample 31: large model time = 3.49s
# Processed sample 32: large model time = 3.28s
# Processed sample 33: large model time = 3.68s
# Processed sample 34: large model time = 1.12s
# Processed sample 35: large model time = 3.91s
# Processed sample 36: large model time = 2.61s
# Processed sample 37: large model time = 3.48s
# Processed sample 38: large model time = 3.71s
# Processed sample 39: large model time = 2.34s
# Processed sample 40: large model time = 4.06s
# Processed sample 41: large model time = 2.84s
# Processed sample 42: large model time = 4.18s
# Processed sample 43: large model time = 1.37s
# Processed sample 44: large model time = 3.28s
# Processed sample 45: large model time = 2.71s
# Processed sample 46: large model time = 3.09s
# Processed sample 47: large model time = 4.30s
# Processed sample 48: large model time = 6.88s
# Processed sample 49: large model time = 2.93s
# Processed sample 50: large model time = 2.92s
# Processed sample 51: large model time = 2.18s
# Processed sample 52: large model time = 1.71s
# Processed sample 53: large model time = 2.27s
# Processed sample 54: large model time = 1.33s
# Processed sample 55: large model time = 1.08s
# Processed sample 56: large model time = 1.32s
# Processed sample 57: large model time = 1.09s
# Processed sample 58: large model time = 4.08s
# Processed sample 59: large model time = 7.44s
# Processed sample 60: large model time = 4.19s
# Processed sample 61: large model time = 4.14s
# Processed sample 62: large model time = 1.26s
# Processed sample 63: large model time = 3.80s
# Processed sample 64: large model time = 2.80s
# Processed sample 65: large model time = 5.64s
# Processed sample 66: large model time = 6.14s
# Processed sample 67: large model time = 3.51s
# Processed sample 68: large model time = 2.63s
# Processed sample 69: large model time = 2.67s
# Processed sample 70: large model time = 3.09s
# Processed sample 71: large model time = 2.83s
# Processed sample 72: large model time = 0.91s
# Processed sample 73: large model time = 0.89s
# Processed sample 74: large model time = 1.94s
# Processed sample 75: large model time = 1.30s
# Processed sample 76: large model time = 4.00s
# Processed sample 77: large model time = 2.63s
# Processed sample 78: large model time = 4.55s
# Processed sample 79: large model time = 6.33s
# Processed sample 80: large model time = 2.45s
# Processed sample 81: large model time = 1.34s
# Processed sample 82: large model time = 5.37s
# Processed sample 83: large model time = 2.01s
# Processed sample 84: large model time = 1.22s
# Processed sample 85: large model time = 1.81s
# Processed sample 86: large model time = 2.83s
# Processed sample 87: large model time = 1.97s
# Processed sample 88: large model time = 1.29s
# Processed sample 89: large model time = 1.53s
# Processed sample 90: large model time = 1.32s
# Processed sample 91: large model time = 1.11s
# Processed sample 92: large model time = 1.11s
# Processed sample 93: large model time = 4.56s
# Processed sample 94: large model time = 1.78s
# Processed sample 95: large model time = 2.40s
# Processed sample 96: large model time = 0.92s
# Processed sample 97: large model time = 0.89s
# Processed sample 98: large model time = 4.54s
# Processed sample 99: large model time = 0.95s
# Processed sample 100: large model time = 1.30s
# Processed sample 101: large model time = 2.78s
# Processed sample 102: large model time = 0.94s
# Processed sample 103: large model time = 0.88s
# Processed sample 104: large model time = 0.88s
# Processed sample 105: large model time = 1.32s
# Processed sample 106: large model time = 2.90s
# Processed sample 107: large model time = 1.27s
# Processed sample 108: large model time = 1.17s
# Processed sample 109: large model time = 1.12s
# Processed sample 110: large model time = 3.46s
# Processed sample 111: large model time = 1.97s
# Processed sample 112: large model time = 0.88s
# Processed sample 113: large model time = 3.77s
# Processed sample 114: large model time = 1.88s
# Processed sample 115: large model time = 2.14s
# Processed sample 116: large model time = 1.32s
# Processed sample 117: large model time = 1.10s
# Processed sample 118: large model time = 2.37s
# Processed sample 119: large model time = 1.61s
# Processed sample 120: large model time = 2.17s
# Processed sample 121: large model time = 1.11s
# Processed sample 122: large model time = 3.04s
# Processed sample 123: large model time = 1.35s
# Processed sample 124: large model time = 0.91s
# Processed sample 125: large model time = 1.96s
# Processed sample 126: large model time = 2.14s
# Processed sample 127: large model time = 1.75s
# Processed sample 128: large model time = 1.41s
# Processed sample 129: large model time = 4.18s
# Processed sample 130: large model time = 1.59s
# Processed sample 131: large model time = 2.55s
# Processed sample 132: large model time = 1.11s
# Processed sample 133: large model time = 4.99s
# Processed sample 134: large model time = 3.28s
# Processed sample 135: large model time = 3.08s
# Processed sample 136: large model time = 1.34s
# Processed sample 137: large model time = 1.54s
# Processed sample 138: large model time = 0.88s
# Processed sample 139: large model time = 1.56s
# Processed sample 140: large model time = 0.87s
# Processed sample 141: large model time = 2.82s
# Processed sample 142: large model time = 2.39s
# Processed sample 143: large model time = 3.65s
# Processed sample 144: large model time = 2.00s
# Processed sample 145: large model time = 1.51s
# Processed sample 146: large model time = 1.09s
# Processed sample 147: large model time = 1.18s
# Processed sample 148: large model time = 1.99s
# Processed sample 149: large model time = 1.20s
# Processed sample 150: large model time = 1.38s
# Processed sample 151: large model time = 3.02s
# Processed sample 152: large model time = 1.54s
# Processed sample 153: large model time = 2.84s
# Processed sample 154: large model time = 7.77s
# Processed sample 155: large model time = 1.16s
# Processed sample 156: large model time = 1.31s
# Processed sample 157: large model time = 2.39s
# Processed sample 158: large model time = 1.54s
# Processed sample 159: large model time = 5.21s
# Processed sample 160: large model time = 3.53s
# Processed sample 161: large model time = 1.76s
# Processed sample 162: large model time = 0.89s
# Processed sample 163: large model time = 1.32s
# Processed sample 164: large model time = 0.90s
# Processed sample 165: large model time = 2.57s
# Processed sample 166: large model time = 3.23s
# Processed sample 167: large model time = 3.08s
# Processed sample 168: large model time = 1.78s
# Processed sample 169: large model time = 5.00s
# Processed sample 170: large model time = 2.40s
# Processed sample 171: large model time = 1.28s
# Processed sample 172: large model time = 2.57s
# Processed sample 173: large model time = 1.38s
# Processed sample 174: large model time = 1.30s
# Processed sample 175: large model time = 1.10s
# Processed sample 176: large model time = 1.08s
# Processed sample 177: large model time = 1.11s
# Processed sample 178: large model time = 3.96s
# Processed sample 179: large model time = 2.20s
# Processed sample 180: large model time = 6.93s
# Processed sample 181: large model time = 1.79s
# Processed sample 182: large model time = 4.03s
# Processed sample 183: large model time = 2.24s
# Processed sample 184: large model time = 0.90s
# Processed sample 185: large model time = 0.88s
# Processed sample 186: large model time = 3.03s
# Processed sample 187: large model time = 1.11s
# Processed sample 188: large model time = 0.87s
# Processed sample 189: large model time = 1.39s
# Processed sample 190: large model time = 1.10s
# Processed sample 191: large model time = 1.82s
# Processed sample 192: large model time = 0.92s
# Processed sample 193: large model time = 0.90s
# Processed sample 194: large model time = 1.31s
# Processed sample 195: large model time = 0.89s
# Processed sample 196: large model time = 0.88s
# Processed sample 197: large model time = 1.93s
# Processed sample 198: large model time = 2.37s
# Processed sample 199: large model time = 2.65s
# Processed sample 200: large model time = 2.81s
# Processed sample 201: large model time = 1.34s
# Processed sample 202: large model time = 2.58s
# Processed sample 203: large model time = 3.73s
# Processed sample 204: large model time = 2.40s
# Processed sample 205: large model time = 6.65s
# Processed sample 206: large model time = 4.15s
# Processed sample 207: large model time = 3.04s
# Processed sample 208: large model time = 6.76s
# Processed sample 209: large model time = 1.99s
# Processed sample 210: large model time = 4.38s
# Processed sample 211: large model time = 6.46s
# Processed sample 212: large model time = 3.11s
# Processed sample 213: large model time = 7.87s
# Processed sample 214: large model time = 2.88s
# Processed sample 215: large model time = 2.63s
# Processed sample 216: large model time = 3.49s
# Processed sample 217: large model time = 5.52s
# Processed sample 218: large model time = 2.21s
# Processed sample 219: large model time = 3.62s
# Processed sample 220: large model time = 2.63s
# Processed sample 221: large model time = 1.72s
# Processed sample 222: large model time = 1.70s
# Processed sample 223: large model time = 6.09s
# Processed sample 224: large model time = 2.21s
# Processed sample 225: large model time = 6.08s
# Processed sample 226: large model time = 1.48s
# Processed sample 227: large model time = 1.11s
# Processed sample 228: large model time = 1.74s
# Processed sample 229: large model time = 2.13s
# Processed sample 230: large model time = 2.57s
# Processed sample 231: large model time = 4.30s
# Processed sample 232: large model time = 1.40s
# Processed sample 233: large model time = 2.99s
# Processed sample 234: large model time = 3.93s
# Processed sample 235: large model time = 2.41s
# Processed sample 236: large model time = 2.03s
# Processed sample 237: large model time = 2.80s
# Processed sample 238: large model time = 3.50s
# Processed sample 239: large model time = 1.59s
# Processed sample 240: large model time = 0.88s
# Processed sample 241: large model time = 0.87s
# Processed sample 242: large model time = 0.88s
# Processed sample 243: large model time = 0.89s
# Processed sample 244: large model time = 2.13s
# Processed sample 245: large model time = 1.56s
# Processed sample 246: large model time = 6.45s
# Processed sample 247: large model time = 1.55s
# Processed sample 248: large model time = 1.10s
# Processed sample 249: large model time = 0.90s
# Processed sample 250: large model time = 1.01s
# Processed sample 251: large model time = 3.25s
# Processed sample 252: large model time = 4.85s
# Processed sample 253: large model time = 0.95s
# Processed sample 254: large model time = 0.89s
# Processed sample 255: large model time = 1.77s
# Processed sample 256: large model time = 6.22s
# Processed sample 257: large model time = 0.94s
# Processed sample 258: large model time = 1.11s
# Processed sample 259: large model time = 2.39s
# Processed sample 260: large model time = 4.51s
# Processed sample 261: large model time = 1.43s
# Processed sample 262: large model time = 2.09s
# Processed sample 263: large model time = 2.32s
# Processed sample 264: large model time = 2.38s
# Processed sample 265: large model time = 2.38s
# Processed sample 266: large model time = 1.96s
# Processed sample 267: large model time = 1.07s
# Processed sample 268: large model time = 1.07s
# Processed sample 269: large model time = 4.05s
# Processed sample 270: large model time = 3.69s
# Processed sample 271: large model time = 2.99s
# Processed sample 272: large model time = 1.10s
# Processed sample 273: large model time = 5.01s
# Processed sample 274: large model time = 3.61s
# Processed sample 275: large model time = 2.66s
# Processed sample 276: large model time = 1.75s
# Processed sample 277: large model time = 1.74s
# Processed sample 278: large model time = 1.18s
# Processed sample 279: large model time = 5.87s
# Processed sample 280: large model time = 1.15s
# Processed sample 281: large model time = 1.29s
# Processed sample 282: large model time = 4.49s
# Processed sample 283: large model time = 2.35s
# Processed sample 284: large model time = 3.00s
# Processed sample 285: large model time = 4.80s
# Processed sample 286: large model time = 1.17s
# Processed sample 287: large model time = 1.10s
# Processed sample 611: large model time = 4.30s
# Processed sample 612: large model time = 1.35s
# Processed sample 613: large model time = 1.08s
# Processed sample 614: large model time = 4.03s
# Processed sample 615: large model time = 1.67s
# Processed sample 616: large model time = 1.51s
# Processed sample 617: large model time = 1.09s
# Processed sample 618: large model time = 1.09s
# Processed sample 619: large model time = 3.71s
# Processed sample 620: large model time = 2.81s
# Processed sample 621: large model time = 2.87s
# Processed sample 622: large model time = 3.55s
# Processed sample 623: large model time = 1.58s
# Processed sample 624: large model time = 1.93s
# Processed sample 625: large model time = 3.43s
# Processed sample 626: large model time = 3.64s
# Processed sample 627: large model time = 2.88s
# Processed sample 628: large model time = 5.38s
# Processed sample 629: large model time = 3.65s
# Processed sample 630: large model time = 2.37s
# Processed sample 631: large model time = 2.65s
# Processed sample 632: large model time = 4.11s
# Processed sample 633: large model time = 6.22s
# Processed sample 634: large model time = 3.05s
# Processed sample 635: large model time = 0.92s
# Processed sample 636: large model time = 2.59s
# Processed sample 637: large model time = 1.33s
# Processed sample 638: large model time = 1.21s
# Processed sample 639: large model time = 1.66s
# Processed sample 640: large model time = 3.88s
# Processed sample 641: large model time = 2.23s
# Processed sample 642: large model time = 3.31s
# Processed sample 643: large model time = 7.20s
# Processed sample 644: large model time = 4.18s
# Processed sample 645: large model time = 6.20s
# Processed sample 646: large model time = 3.28s
# Processed sample 647: large model time = 1.35s
# Processed sample 648: large model time = 2.16s
# Processed sample 649: large model time = 1.32s
# Processed sample 650: large model time = 2.03s
# Processed sample 651: large model time = 4.61s
# Processed sample 652: large model time = 5.79s
# Processed sample 653: large model time = 1.57s
# Processed sample 654: large model time = 1.51s
# Processed sample 655: large model time = 0.87s
# Processed sample 656: large model time = 1.10s
# Processed sample 657: large model time = 1.82s
# Processed sample 658: large model time = 2.10s
# Processed sample 659: large model time = 1.39s
# Processed sample 660: large model time = 1.10s
# Processed sample 661: large model time = 1.94s
# Processed sample 662: large model time = 1.10s
# Processed sample 663: large model time = 3.20s
# Processed sample 664: large model time = 1.16s
# Processed sample 665: large model time = 5.11s
# Processed sample 666: large model time = 1.36s
# Processed sample 667: large model time = 1.74s
# Processed sample 668: large model time = 1.30s
# Processed sample 669: large model time = 0.88s
# Processed sample 670: large model time = 1.31s
# Processed sample 671: large model time = 3.46s
# Processed sample 672: large model time = 3.43s
# Processed sample 673: large model time = 0.95s
# Processed sample 674: large model time = 3.00s
# Processed sample 675: large model time = 1.34s
# Processed sample 676: large model time = 0.89s
# Processed sample 677: large model time = 4.42s
# Processed sample 678: large model time = 3.49s
# Processed sample 679: large model time = 6.09s
# Processed sample 680: large model time = 8.52s
# Processed sample 681: large model time = 2.45s
# Processed sample 682: large model time = 1.57s
# Processed sample 683: large model time = 1.74s
# Processed sample 684: large model time = 1.74s
# Processed sample 685: large model time = 2.38s
# Processed sample 686: large model time = 3.84s
# Processed sample 687: large model time = 1.14s
# Processed sample 688: large model time = 1.10s
# Processed sample 689: large model time = 1.74s
# Processed sample 690: large model time = 6.27s
# Processed sample 691: large model time = 1.56s
# Processed sample 692: large model time = 2.99s
# Processed sample 693: large model time = 2.82s
# Processed sample 694: large model time = 1.75s
# Processed sample 695: large model time = 7.84s
# Processed sample 696: large model time = 4.41s
# Processed sample 697: large model time = 3.94s
# Processed sample 698: large model time = 1.55s
# Processed sample 699: large model time = 2.68s
# Processed sample 700: large model time = 1.46s
# Processed sample 701: large model time = 3.42s
# Processed sample 702: large model time = 2.61s
# Processed sample 703: large model time = 1.14s
# Processed sample 704: large model time = 2.82s
# Processed sample 705: large model time = 3.19s
# Processed sample 706: large model time = 1.58s
# Processed sample 707: large model time = 0.89s
# Processed sample 708: large model time = 4.36s
# Processed sample 709: large model time = 0.95s
# Processed sample 710: large model time = 1.82s
# Processed sample 711: large model time = 1.12s
# Processed sample 712: large model time = 4.84s
# Processed sample 713: large model time = 5.66s
# Processed sample 714: large model time = 0.93s
# Processed sample 715: large model time = 5.32s
# Processed sample 716: large model time = 1.36s
# Processed sample 717: large model time = 6.60s
# Processed sample 718: large model time = 0.96s
# Processed sample 719: large model time = 7.48s
# Processed sample 720: large model time = 3.11s
# Processed sample 721: large model time = 3.96s
# Processed sample 722: large model time = 1.44s
# Processed sample 723: large model time = 2.10s
# Processed sample 724: large model time = 1.31s
# Processed sample 725: large model time = 3.84s
# Processed sample 726: large model time = 2.00s
# Processed sample 727: large model time = 5.08s
# Processed sample 728: large model time = 3.14s
# Processed sample 729: large model time = 2.17s
# Processed sample 730: large model time = 2.21s
# Processed sample 731: large model time = 4.10s
# Processed sample 732: large model time = 2.37s
# Processed sample 733: large model time = 1.85s
# Processed sample 734: large model time = 1.30s
# Processed sample 735: large model time = 2.43s
# Processed sample 736: large model time = 1.97s
# Processed sample 737: large model time = 2.58s
# Processed sample 738: large model time = 3.56s
# Processed sample 739: large model time = 2.12s
# Processed sample 740: large model time = 2.80s
# Processed sample 741: large model time = 3.03s
# Processed sample 742: large model time = 1.33s
# Processed sample 743: large model time = 4.11s
# Processed sample 744: large model time = 3.30s
# Processed sample 745: large model time = 3.24s
# Processed sample 746: large model time = 2.18s
# Processed sample 747: large model time = 1.93s
# Processed sample 748: large model time = 1.46s
# Processed sample 749: large model time = 1.39s
# Processed sample 750: large model time = 3.95s
# Processed sample 751: large model time = 2.23s
# Processed sample 752: large model time = 1.12s
# Processed sample 753: large model time = 10.69s
# Processed sample 754: large model time = 1.76s
# Processed sample 755: large model time = 1.74s
# Processed sample 756: large model time = 3.02s
# Processed sample 757: large model time = 3.38s
# Processed sample 758: large model time = 1.90s
# Processed sample 759: large model time = 1.12s
# Processed sample 760: large model time = 1.51s
# Processed sample 761: large model time = 3.74s
# Processed sample 762: large model time = 0.94s
# Processed sample 763: large model time = 1.72s
# Processed sample 764: large model time = 4.51s
# Processed sample 765: large model time = 2.23s
# Processed sample 766: large model time = 1.09s
# Processed sample 767: large model time = 3.90s
# Processed sample 768: large model time = 5.64s
# Processed sample 769: large model time = 2.25s
# Processed sample 770: large model time = 1.52s
# Processed sample 771: large model time = 0.89s
# Processed sample 772: large model time = 3.90s
# Processed sample 773: large model time = 0.94s
# Processed sample 774: large model time = 3.65s
# Processed sample 775: large model time = 3.32s
# Processed sample 776: large model time = 0.91s
# Processed sample 777: large model time = 2.55s
# Processed sample 778: large model time = 4.78s
# Processed sample 779: large model time = 1.15s
# Processed sample 780: large model time = 3.45s
# Processed sample 781: large model time = 0.94s
# Processed sample 782: large model time = 4.11s
# Processed sample 783: large model time = 0.95s
# Processed sample 784: large model time = 0.89s
# Processed sample 785: large model time = 1.09s
# Processed sample 786: large model time = 0.89s
# Processed sample 787: large model time = 4.97s
# Processed sample 788: large model time = 1.15s
# Processed sample 789: large model time = 1.31s
# Processed sample 790: large model time = 3.88s
# Processed sample 791: large model time = 1.34s
# Processed sample 792: large model time = 3.85s
# Processed sample 793: large model time = 1.22s
# Processed sample 794: large model time = 3.22s
# Processed sample 795: large model time = 4.10s
# Processed sample 796: large model time = 0.91s
# Processed sample 797: large model time = 2.40s
# Processed sample 798: large model time = 3.50s
# Processed sample 799: large model time = 0.93s
# Processed sample 800: large model time = 3.61s
# Processed sample 801: large model time = 1.57s
# Processed sample 802: large model time = 0.88s
# Processed sample 803: large model time = 2.14s
# Processed sample 804: large model time = 5.01s
# Processed sample 805: large model time = 1.37s
# Processed sample 806: large model time = 2.15s
# Processed sample 807: large model time = 4.74s
# Processed sample 808: large model time = 1.02s
# Processed sample 809: large model time = 4.61s
# Processed sample 810: large model time = 1.82s
# Processed sample 811: large model time = 3.87s
# Processed sample 812: large model time = 2.18s
# Processed sample 813: large model time = 4.57s
# Processed sample 814: large model time = 3.68s
# Processed sample 815: large model time = 4.12s
# Processed sample 816: large model time = 0.95s
# Processed sample 817: large model time = 1.10s
# Processed sample 818: large model time = 3.90s
# Processed sample 819: large model time = 1.38s
# Processed sample 820: large model time = 1.33s
# Processed sample 821: large model time = 2.24s
# Processed sample 822: large model time = 4.30s
# Processed sample 823: large model time = 2.72s
# Processed sample 824: large model time = 1.98s
# Processed sample 825: large model time = 0.88s
# Processed sample 826: large model time = 6.87s
# Processed sample 827: large model time = 8.15s
# Processed sample 828: large model time = 1.58s
# Processed sample 829: large model time = 1.32s
# Processed sample 830: large model time = 1.11s
# Processed sample 831: large model time = 1.55s
# Processed sample 832: large model time = 5.55s
# Processed sample 833: large model time = 0.93s
# Processed sample 834: large model time = 2.63s
# Processed sample 835: large model time = 5.00s
# Processed sample 836: large model time = 6.92s
# Processed sample 837: large model time = 1.18s
# Processed sample 838: large model time = 2.18s
# Processed sample 839: large model time = 3.01s
# Processed sample 840: large model time = 1.70s
# Processed sample 841: large model time = 1.44s
# Processed sample 842: large model time = 2.19s
# Processed sample 843: large model time = 0.91s
# Processed sample 844: large model time = 2.96s
# Processed sample 845: large model time = 0.91s
# Processed sample 846: large model time = 0.87s
# Processed sample 847: large model time = 0.88s
# Processed sample 848: large model time = 1.09s
# Processed sample 849: large model time = 0.88s
# Processed sample 850: large model time = 0.96s
# Processed sample 851: large model time = 3.54s
# Processed sample 852: large model time = 3.55s
# Processed sample 853: large model time = 0.93s
# Processed sample 854: large model time = 2.56s
# Processed sample 855: large model time = 3.54s
# Processed sample 856: large model time = 4.39s
# Processed sample 857: large model time = 4.50s
# Processed sample 858: large model time = 2.62s
# Processed sample 859: large model time = 4.73s
# Processed sample 860: large model time = 2.21s
# Processed sample 861: large model time = 3.85s
# Processed sample 862: large model time = 6.33s
# Processed sample 863: large model time = 2.49s
# Processed sample 864: large model time = 6.03s
# Processed sample 865: large model time = 6.74s
# Processed sample 866: large model time = 3.87s
# Processed sample 867: large model time = 4.16s
# Processed sample 868: large model time = 4.39s
# Processed sample 869: large model time = 8.43s
# Processed sample 870: large model time = 0.94s
# Processed sample 871: large model time = 3.29s
# Processed sample 872: large model time = 1.72s
# Processed sample 873: large model time = 3.67s
# Processed sample 874: large model time = 4.32s
# Processed sample 875: large model time = 2.61s
# Processed sample 876: large model time = 5.23s
# Processed sample 877: large model time = 2.87s
# Processed sample 878: large model time = 1.57s
# Processed sample 879: large model time = 2.60s
# Processed sample 880: large model time = 2.02s
# Processed sample 881: large model time = 1.66s
# Processed sample 882: large model time = 2.34s
# Processed sample 883: large model time = 3.53s
# Processed sample 884: large model time = 3.28s
# Processed sample 885: large model time = 4.98s
# Processed sample 886: large model time = 5.21s
# Processed sample 887: large model time = 3.67s
# Processed sample 888: large model time = 3.10s
# Processed sample 889: large model time = 5.83s
# Processed sample 890: large model time = 1.15s
# Processed sample 891: large model time = 1.10s
# Processed sample 892: large model time = 3.65s
# Processed sample 893: large model time = 7.57s
# Processed sample 894: large model time = 2.83s
# Processed sample 895: large model time = 1.55s
# Processed sample 896: large model time = 1.31s
# Processed sample 897: large model time = 2.17s
# Processed sample 898: large model time = 2.03s
# Processed sample 899: large model time = 4.72s
# Processed sample 900: large model time = 0.93s
# Processed sample 901: large model time = 1.92s
# Processed sample 902: large model time = 2.80s
# Processed sample 903: large model time = 3.32s
# Processed sample 904: large model time = 1.50s
# Processed sample 905: large model time = 1.87s
# Processed sample 906: large model time = 2.77s
# Processed sample 907: large model time = 1.15s
# Processed sample 908: large model time = 4.59s
# Processed sample 909: large model time = 2.18s
# Processed sample 910: large model time = 1.85s
# Processed sample 911: large model time = 4.24s
# Processed sample 912: large model time = 1.76s
# Processed sample 913: large model time = 2.36s
# Processed sample 914: large model time = 1.56s
# Processed sample 915: large model time = 4.10s
# Processed sample 916: large model time = 3.31s
# Processed sample 917: large model time = 2.20s
# Processed sample 918: large model time = 4.11s
# Processed sample 919: large model time = 2.62s
# Processed sample 920: large model time = 1.26s
# Processed sample 921: large model time = 1.33s
# Processed sample 922: large model time = 4.11s
# Processed sample 923: large model time = 3.47s
# Processed sample 924: large model time = 2.05s
# Processed sample 925: large model time = 2.13s
# Processed sample 926: large model time = 2.62s
# Processed sample 927: large model time = 3.64s
# Processed sample 928: large model time = 1.99s
# Processed sample 929: large model time = 4.32s
# Processed sample 930: large model time = 2.61s
# Processed sample 931: large model time = 1.75s
# Processed sample 932: large model time = 1.34s
# Processed sample 933: large model time = 4.17s
# Processed sample 934: large model time = 7.37s
# Processed sample 935: large model time = 1.36s
# Processed sample 936: large model time = 1.28s
# Processed sample 937: large model time = 2.43s
# Processed sample 938: large model time = 1.33s
# Processed sample 939: large model time = 2.64s
# Processed sample 940: large model time = 1.48s
# Processed sample 941: large model time = 2.87s
# Processed sample 942: large model time = 2.48s
# Processed sample 943: large model time = 4.64s
# Processed sample 944: large model time = 0.94s
# Processed sample 945: large model time = 1.42s
# Processed sample 946: large model time = 6.54s
# Processed sample 947: large model time = 0.94s
# Processed sample 948: large model time = 1.29s
# Processed sample 949: large model time = 0.88s
# Processed sample 950: large model time = 2.61s
# Processed sample 951: large model time = 4.66s
# Processed sample 952: large model time = 2.63s
# Processed sample 953: large model time = 5.71s
# Processed sample 954: large model time = 3.89s
# Processed sample 955: large model time = 1.58s
# Processed sample 956: large model time = 5.83s
# Processed sample 957: large model time = 1.36s
# Processed sample 958: large model time = 5.39s
# Processed sample 959: large model time = 1.61s
# Processed sample 960: large model time = 6.70s
# Processed sample 961: large model time = 1.69s
# Processed sample 962: large model time = 7.93s
# Processed sample 963: large model time = 6.83s
# Processed sample 964: large model time = 4.51s
# Processed sample 965: large model time = 0.94s
# Processed sample 966: large model time = 1.94s
# Processed sample 967: large model time = 8.18s
# Processed sample 968: large model time = 4.84s
# Processed sample 969: large model time = 5.19s
# Processed sample 970: large model time = 8.30s
# Processed sample 971: large model time = 1.80s
# Processed sample 972: large model time = 3.01s
# Processed sample 973: large model time = 3.59s
# Processed sample 974: large model time = 4.33s
# Processed sample 975: large model time = 3.70s
# Processed sample 976: large model time = 6.21s
# Processed sample 977: large model time = 1.69s
# Processed sample 978: large model time = 3.23s
# Processed sample 979: large model time = 3.46s
# Processed sample 980: large model time = 6.53s
# Processed sample 981: large model time = 5.05s
# Processed sample 982: large model time = 5.98s
# Processed sample 983: large model time = 7.08s
# Processed sample 984: large model time = 2.39s
# Processed sample 985: large model time = 1.76s
# Processed sample 986: large model time = 6.63s
# Processed sample 987: large model time = 4.80s
# Processed sample 988: large model time = 6.77s
# Processed sample 989: large model time = 1.40s
# Processed sample 990: large model time = 3.65s
# Processed sample 991: large model time = 7.28s
# Processed sample 992: large model time = 3.22s
# Processed sample 993: large model time = 3.26s
# ...
# Processed sample 2847: large model time = 1.39s
# Processed sample 2848: large model time = 0.88s
# Processed sample 2849: large model time = 14.60s
# Processed sample 2850: large model time = 2.40s
# Processed sample 2851: large model time = 2.15s
# Processed sample 2852: large model time = 0.91s
# Processed sample 2853: large model time = 1.83s
# Processed sample 2854: large model time = 7.66s
# Processed sample 2855: large model time = 14.82s
# Processed sample 2856: large model time = 4.11s
# Processed sample 2857: large model time = 0.93s
# Processed sample 2858: large model time = 1.13s
# Processed sample 2859: large model time = 4.88s
# Processed sample 2860: large model time = 5.39s
# Processed sample 2861: large model time = 0.97s
# Processed sample 2862: large model time = 1.10s
# Processed sample 2863: large model time = 2.44s
# Processed sample 2864: large model time = 2.61s
# Processed sample 2865: large model time = 0.92s
# Processed sample 2866: large model time = 2.74s
# Processed sample 2867: large model time = 3.63s
# Processed sample 2868: large model time = 0.96s
# Processed sample 2869: large model time = 2.51s
# Processed sample 2870: large model time = 2.14s
# Processed sample 2871: large model time = 0.89s
# Processed sample 2872: large model time = 6.21s
# Processed sample 2873: large model time = 2.18s
# Processed sample 2874: large model time = 4.91s
# Processed sample 2875: large model time = 2.68s
# Processed sample 2876: large model time = 2.36s
# Processed sample 2877: large model time = 1.76s
# Processed sample 2878: large model time = 15.20s
# Processed sample 2879: large model time = 1.04s
# Processed sample 2880: large model time = 10.42s
# Processed sample 2881: large model time = 0.93s
# Processed sample 2882: large model time = 3.22s
# Processed sample 2883: large model time = 1.80s
# Processed sample 2884: large model time = 1.69s
# Processed sample 2885: large model time = 1.10s
# Processed sample 2886: large model time = 1.51s
# Processed sample 2887: large model time = 1.51s
# Processed sample 2888: large model time = 1.09s
# Processed sample 2889: large model time = 1.51s
# Processed sample 2890: large model time = 1.74s
# Processed sample 2891: large model time = 3.46s
# Processed sample 2892: large model time = 3.51s
# Processed sample 2893: large model time = 2.41s
# Processed sample 2894: large model time = 5.53s
# Processed sample 2895: large model time = 2.69s
# Processed sample 2896: large model time = 1.17s
# Processed sample 2897: large model time = 1.52s
# Processed sample 2898: large model time = 2.33s
# Processed sample 2899: large model time = 2.18s
# Processed sample 2900: large model time = 4.68s
# Processed sample 2901: large model time = 2.94s
# Processed sample 2902: large model time = 3.87s
# Processed sample 2903: large model time = 4.99s
# Processed sample 2904: large model time = 3.92s
# Processed sample 2905: large model time = 1.16s
# Processed sample 2906: large model time = 5.11s
# Processed sample 2907: large model time = 2.17s
# Processed sample 2908: large model time = 1.72s
# Processed sample 2909: large model time = 2.96s
# Processed sample 2910: large model time = 1.23s
# Processed sample 2911: large model time = 4.23s
# Processed sample 2912: large model time = 1.76s
# Processed sample 2913: large model time = 2.57s
# Processed sample 2914: large model time = 3.63s
# Processed sample 2915: large model time = 2.87s
# Processed sample 2916: large model time = 3.64s
# Processed sample 2917: large model time = 1.14s
# Processed sample 2918: large model time = 7.09s
# Processed sample 2919: large model time = 3.08s
# Processed sample 2920: large model time = 3.43s
# Processed sample 2921: large model time = 1.55s
# Processed sample 2922: large model time = 2.01s
# Processed sample 2923: large model time = 3.71s
# Processed sample 2924: large model time = 4.48s
# Processed sample 2925: large model time = 1.14s
# Processed sample 2926: large model time = 1.09s
# Processed sample 2927: large model time = 1.08s
# Processed sample 2928: large model time = 3.89s
# Processed sample 2929: large model time = 3.23s
# Processed sample 2930: large model time = 3.25s
# Processed sample 2931: large model time = 5.63s
# Processed sample 2932: large model time = 2.16s
# Processed sample 2933: large model time = 1.51s
# Processed sample 2934: large model time = 2.21s
# Processed sample 2935: large model time = 1.12s
# Processed sample 2936: large model time = 0.89s
# Processed sample 2937: large model time = 1.13s
# Processed sample 2938: large model time = 1.10s
# Processed sample 2939: large model time = 2.36s
# Processed sample 2940: large model time = 1.12s
# Processed sample 2941: large model time = 1.92s
# Processed sample 2942: large model time = 3.53s
# Processed sample 2943: large model time = 3.04s
# Processed sample 2944: large model time = 1.95s
# Processed sample 2945: large model time = 1.90s
# Processed sample 2946: large model time = 5.11s
# Processed sample 2947: large model time = 4.40s
# Processed sample 2948: large model time = 4.35s
# Processed sample 2949: large model time = 5.49s
# Processed sample 2950: large model time = 5.24s
# Processed sample 2951: large model time = 5.25s
# Processed sample 2952: large model time = 2.05s
# Processed sample 2953: large model time = 3.47s
# Processed sample 2954: large model time = 1.16s
# Processed sample 2955: large model time = 0.91s
# Processed sample 2956: large model time = 2.15s
# Processed sample 2957: large model time = 3.18s
# Processed sample 2958: large model time = 2.67s
# Processed sample 2959: large model time = 3.43s
# Processed sample 2960: large model time = 2.21s
# Processed sample 2961: large model time = 2.17s
# Processed sample 2962: large model time = 1.51s
# Processed sample 2963: large model time = 2.15s
# Processed sample 2964: large model time = 5.67s
# Processed sample 2965: large model time = 1.80s
# Processed sample 2966: large model time = 5.34s
# Processed sample 2967: large model time = 6.58s
# Processed sample 2968: large model time = 2.18s
# Processed sample 2969: large model time = 1.08s
# Processed sample 2970: large model time = 2.14s
# Processed sample 2971: large model time = 1.53s
# Processed sample 2972: large model time = 3.28s
# Processed sample 2973: large model time = 2.40s
# Processed sample 2974: large model time = 1.74s
# Processed sample 2975: large model time = 5.62s
# Processed sample 2976: large model time = 3.64s
# Processed sample 2977: large model time = 2.78s
# Processed sample 2978: large model time = 2.03s
# Processed sample 2979: large model time = 2.77s
# Processed sample 2980: large model time = 3.25s
# Processed sample 2981: large model time = 3.44s
# Processed sample 2982: large model time = 3.89s
# Processed sample 2983: large model time = 1.35s
# Processed sample 2984: large model time = 4.91s
# Processed sample 2985: large model time = 0.94s
# Processed sample 2986: large model time = 0.88s
# Processed sample 2987: large model time = 3.54s
# Processed sample 2988: large model time = 2.23s
# Processed sample 2989: large model time = 3.71s
# Processed sample 2990: large model time = 3.04s
# Processed sample 2991: large model time = 1.93s
# Processed sample 2992: large model time = 3.19s
# Processed sample 2993: large model time = 2.61s
# Processed sample 2994: large model time = 2.41s
# Processed sample 2995: large model time = 1.76s
# Processed sample 2996: large model time = 1.94s
# Processed sample 2997: large model time = 1.76s
# Processed sample 2998: large model time = 1.12s
# Processed sample 2999: large model time = 1.25s
# Processed sample 3000: large model time = 1.17s
# Processed sample 3001: large model time = 1.30s
# Processed sample 3002: large model time = 1.72s
# Processed sample 3003: large model time = 1.73s
# Processed sample 3004: large model time = 2.59s
# Processed sample 3005: large model time = 2.02s
# Processed sample 3006: large model time = 2.27s
# Processed sample 3007: large model time = 1.57s
# Processed sample 3008: large model time = 1.92s
# Processed sample 3009: large model time = 2.16s
# Processed sample 3010: large model time = 3.87s
# Processed sample 3011: large model time = 2.78s
# Processed sample 3012: large model time = 2.75s
# Processed sample 3013: large model time = 2.64s
# Processed sample 3014: large model time = 1.75s
# Processed sample 3015: large model time = 1.09s
# Processed sample 3016: large model time = 1.52s
# Processed sample 3017: large model time = 3.35s
# Processed sample 3018: large model time = 2.92s
# Processed sample 3019: large model time = 1.74s
# Processed sample 3020: large model time = 1.92s
# Processed sample 3021: large model time = 1.92s
# Processed sample 3022: large model time = 1.50s
# Processed sample 3023: large model time = 1.09s
# Processed sample 3024: large model time = 4.61s
# Processed sample 3025: large model time = 2.14s
# Processed sample 3026: large model time = 4.73s
# Processed sample 3027: large model time = 2.17s
# Processed sample 3028: large model time = 2.39s
# Processed sample 3029: large model time = 3.54s
# Processed sample 3030: large model time = 2.80s
# Processed sample 3031: large model time = 3.94s
# Processed sample 3032: large model time = 1.34s
# Processed sample 3033: large model time = 1.10s
# Processed sample 3034: large model time = 2.45s
# Processed sample 3035: large model time = 4.24s
# Processed sample 3036: large model time = 2.43s
# Processed sample 3037: large model time = 2.19s
# Processed sample 3038: large model time = 1.72s
# Processed sample 3039: large model time = 3.63s
# Processed sample 3040: large model time = 2.10s
# Processed sample 3041: large model time = 1.97s
# Processed sample 3042: large model time = 2.36s
# Processed sample 3043: large model time = 3.02s
# Processed sample 3044: large model time = 1.54s
# Processed sample 3045: large model time = 3.50s
# Processed sample 3046: large model time = 4.58s
# Processed sample 3047: large model time = 3.04s
# Processed sample 3048: large model time = 2.63s
# Processed sample 3049: large model time = 2.97s
# Processed sample 3050: large model time = 1.72s
# Processed sample 3051: large model time = 0.88s
# Processed sample 3052: large model time = 3.69s
# Processed sample 3053: large model time = 1.15s
# Processed sample 3054: large model time = 1.94s
# Processed sample 3055: large model time = 0.88s
# Processed sample 3056: large model time = 1.10s
# Processed sample 3057: large model time = 3.47s
# Processed sample 3058: large model time = 0.94s
# Processed sample 3059: large model time = 1.09s
# Processed sample 3060: large model time = 1.08s
# Processed sample 3061: large model time = 3.87s
# Processed sample 3062: large model time = 1.99s
# Processed sample 3063: large model time = 1.53s
# Processed sample 3064: large model time = 3.49s
# Processed sample 3065: large model time = 2.41s
# Processed sample 3066: large model time = 3.28s
# Processed sample 3067: large model time = 2.19s
# Processed sample 3068: large model time = 2.35s
# Processed sample 3069: large model time = 4.29s
# Processed sample 3070: large model time = 3.46s
# Processed sample 3071: large model time = 7.82s
# Processed sample 3072: large model time = 5.10s
# Processed sample 3073: large model time = 0.94s
# Processed sample 3074: large model time = 5.45s
# Processed sample 3075: large model time = 1.72s
# Processed sample 3076: large model time = 1.52s
# Processed sample 3077: large model time = 1.22s
# Processed sample 3078: large model time = 1.28s
# Processed sample 3079: large model time = 1.48s
# Processed sample 3080: large model time = 1.92s
# Processed sample 3081: large model time = 1.52s
# Processed sample 3082: large model time = 2.14s
# Processed sample 3083: large model time = 6.75s
# Processed sample 3084: large model time = 3.24s
# Processed sample 3085: large model time = 1.95s
# Processed sample 3086: large model time = 2.66s
# Processed sample 3087: large model time = 4.05s
# Processed sample 3088: large model time = 2.01s
# Processed sample 3089: large model time = 8.11s
# Processed sample 3090: large model time = 4.61s
# Processed sample 3091: large model time = 3.05s
# Processed sample 3092: large model time = 8.30s
# Processed sample 3093: large model time = 3.61s
# Processed sample 3094: large model time = 3.62s
# Processed sample 3095: large model time = 3.57s
# Processed sample 3096: large model time = 2.97s
# Processed sample 3097: large model time = 5.93s
# Processed sample 3098: large model time = 3.03s
# Processed sample 3099: large model time = 4.19s
# Processed sample 3100: large model time = 1.73s
# Processed sample 3101: large model time = 2.16s
# Processed sample 3102: large model time = 8.12s
# Processed sample 3103: large model time = 2.40s
# Processed sample 3104: large model time = 1.76s
# Processed sample 3105: large model time = 1.28s
# Processed sample 3106: large model time = 6.65s
# Processed sample 3107: large model time = 1.16s
# Processed sample 3108: large model time = 2.28s
# Processed sample 3109: large model time = 1.21s
# Processed sample 3110: large model time = 3.70s
# Processed sample 3111: large model time = 0.90s
# Processed sample 3112: large model time = 0.87s
# Processed sample 3113: large model time = 0.92s
# Processed sample 3114: large model time = 1.09s
# Processed sample 3115: large model time = 2.13s
# Processed sample 3116: large model time = 1.00s
# Processed sample 3117: large model time = 1.99s
# Processed sample 3118: large model time = 2.51s
# Processed sample 3119: large model time = 2.16s
# Processed sample 3120: large model time = 2.19s
# Processed sample 3121: large model time = 2.98s
# Processed sample 3122: large model time = 2.89s
# Processed sample 3123: large model time = 1.24s
# Processed sample 3124: large model time = 1.17s
# Processed sample 3125: large model time = 2.32s
# Processed sample 3126: large model time = 3.45s
# Processed sample 3127: large model time = 5.11s
# Processed sample 3128: large model time = 3.28s
# Processed sample 3129: large model time = 2.21s
# Processed sample 3130: large model time = 4.53s
# Processed sample 3131: large model time = 1.57s
# Processed sample 3132: large model time = 4.58s
# Processed sample 3133: large model time = 4.83s
# Processed sample 3134: large model time = 1.15s
# Processed sample 3135: large model time = 0.88s
# Processed sample 3136: large model time = 4.32s
# Processed sample 3137: large model time = 3.50s
# Processed sample 3138: large model time = 1.76s
# Processed sample 3139: large model time = 2.36s
# Processed sample 3140: large model time = 1.11s
# Processed sample 3141: large model time = 3.81s
# Processed sample 3142: large model time = 1.91s
# Processed sample 3143: large model time = 3.41s
# Processed sample 3144: large model time = 2.19s
# Processed sample 3145: large model time = 1.10s
# Processed sample 3146: large model time = 1.52s
# Processed sample 3147: large model time = 1.09s
#                                    reference  \
# 0                                    hai weh
# 1     ah makanan bagi aku macam struggle kan
# 2      makanan yang sedap kat Malaysia ni tu
# 3                                     kenapa
# 4                        dia punya dia punya
# ...                                      ...
# 3143      okey aku pun tu je la makanan yang
# 3144                   makanan kegemaran aku
# 3145                                      so
# 3146                              jumpa lagi
# 3147                                 bye bye
#
#                 whisper_large_v3_prediction  whisper_large_v3_process_time
# 0                                   hai weh                       4.771178
# 1     ah makanan bagi aku macam suggest kan                       2.652175
# 2     makanan yang sedap kat Malaysia ni tu                       2.643847
# 3                                    kenapa                       1.154674
# 4                       dia punya dia punya                       1.750382
# ...                                     ...                            ...
# 3143   okey aku pun itu je lah makanan yang                       3.413080
# 3144                  makanan kegemaran aku                       2.192711
# 3145                                    sob                       1.103134
# 3146                             jumpa lagi                       1.519158
# 3147                                bye bye                       1.092564
#
# [3148 rows x 3 columns]

# %%
df_results.to_csv("peft_evaluate_large_epoch_20.csv", index=False)

# !cp {"peft_evaluate_large_epoch_20.csv"} "/content/drive/MyDrive/"
