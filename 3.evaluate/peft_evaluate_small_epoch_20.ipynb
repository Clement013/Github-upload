# %%
# !pip install -q bitsandbytes peft datasets[audio] jiwer

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
from transformers import (
    AutomaticSpeechRecognitionPipeline,
    WhisperForConditionalGeneration,
    WhisperTokenizer,
    WhisperProcessor,
)
from peft import PeftModel, PeftConfig
import torch
class SpeechRecognizer:
    def __init__(self, peft_model_id, language="malay", task="transcribe"):
        # Store the language and task
        self.language = language
        self.task = task

        # Load PeftConfig
        self.peft_model_id = peft_model_id
        peft_config = PeftConfig.from_pretrained(self.peft_model_id)

        # Load the model, tokenizer, processor, and other necessary components
        self.model = WhisperForConditionalGeneration.from_pretrained(
            peft_config.base_model_name_or_path, load_in_8bit=True, device_map="auto"
        )
        self.model = PeftModel.from_pretrained(self.model, self.peft_model_id)
        self.tokenizer = WhisperTokenizer.from_pretrained(peft_config.base_model_name_or_path, language=self.language, task=self.task)
        self.processor = WhisperProcessor.from_pretrained(peft_config.base_model_name_or_path, language=self.language, task=self.task)
        self.feature_extractor = self.processor.feature_extractor
        self.forced_decoder_ids = self.processor.get_decoder_prompt_ids(language=self.language, task=self.task)

        # Initialize the pipeline for ASR
        self.pipe = AutomaticSpeechRecognitionPipeline(
            model=self.model, tokenizer=self.tokenizer, feature_extractor=self.feature_extractor
        )

    def transcribe(self, audio_file):
        # Perform transcription with automatic mixed precision if CUDA is available
        if torch.cuda.is_available():
            with torch.cuda.amp.autocast():
                result = self.pipe(audio_file, generate_kwargs={"forced_decoder_ids": self.forced_decoder_ids}, max_new_tokens=255)
        else:
            result = self.pipe(audio_file, generate_kwargs={"forced_decoder_ids": self.forced_decoder_ids}, max_new_tokens=255)

        # Return the transcribed text
        return result["text"]

# %%
peft_model_id_1 = "clt013/whisper-large-v3-ft-malay-peft-v1"
perf_model_id_2 = "clt013/whisper-small-ft-malay-peft-epoch-20"
# whisper_large_v3_recognizer = SpeechRecognizer(peft_model_id=peft_model_id_1)
whisper_small_recognizer = SpeechRecognizer(peft_model_id=perf_model_id_2)
# Out:
# adapter_config.json:   0%|          | 0.00/768 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.97k [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.87k [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/14.2M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]

# %%
# save to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import time
from datasets import load_dataset, concatenate_datasets

def transcribe_and_compare(dataset_name, whisper_small_recognizer,
                           #whisper_large_v3_recognizer,
                           limit=10, limited=False):
    """
    Transcribe audio samples from the dataset using two different Whisper models, compare the transcriptions,
    and measure the processing time for each transcription.

    Args:
    - dataset_name (str): The name of the dataset to load.
    - whisper_small_recognizer: The recognizer object for the small Whisper model.
    - whisper_large_v3_recognizer: The recognizer object for the large Whisper model.
    - limit (int): The number of samples to process if 'limited' is True.
    - limited (bool): Whether to limit the number of samples processed.

    Returns:
    - df (DataFrame): A pandas DataFrame containing the reference sentence, transcriptions,
                      and processing times for the two Whisper models.
    """
    # Load the dataset
    dataset = load_dataset(dataset_name)

    # Concatenate train and test sets
    concatenated_dataset = concatenate_datasets([dataset["train"], dataset["test"]])

    # Prepare to store the results
    df_list = []

    # Loop through the dataset, limited by the specified amount if necessary
    for i in range(limit if limited else len(concatenated_dataset)):
        audio_sample = concatenated_dataset[i]['audio']
        samples = audio_sample['array']
        reference = concatenated_dataset[i]['sentence']

        # Transcribe using whisper_small_recognizer and measure processing time
        start_time_small = time.time()
        transcribed_1 = whisper_small_recognizer.transcribe(audio_sample)
        end_time_small = time.time()
        process_time_small = end_time_small - start_time_small

        # Transcribe using whisper_large_v3_recognizer and measure processing time
        # start_time_large = time.time()
        # audio_sample = concatenated_dataset[i]['audio']
        # transcribed_2 = whisper_large_v3_recognizer.transcribe(audio_sample)
        # end_time_large = time.time()
        # process_time_large = end_time_large - start_time_large

        # Append the results to the list, including processing times
        df_list.append(pd.DataFrame({
            'reference': [reference],
            'whisper_small_prediction': [transcribed_1],
            # 'whisper_large_v3_prediction': [transcribed_2],
            'whisper_small_process_time': [process_time_small],
            # 'whisper_large_v3_process_time': [process_time_large]
        }))

        print(f"Processed sample {i}: small model time = {process_time_small:.2f}s")
        #, large model time = {process_time_large:.2f}s")

    # Combine the results into a single DataFrame
    df = pd.concat(df_list, ignore_index=True)

    return df

# %%
df_results = transcribe_and_compare("clt013/malay-speech-3k-rows-dataset_v2", whisper_small_recognizer)
df_results
# Out:
# README.md:   0%|          | 0.00/460 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/216M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/59.7M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2544 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/604 [00:00<?, ? examples/s]
# <ipython-input-4-bd40256c27b2>:37: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:316: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Processed sample 0: small model time = 3.55s
# Processed sample 1: small model time = 1.38s
# Processed sample 2: small model time = 1.31s
# Processed sample 3: small model time = 0.55s
# Processed sample 4: small model time = 0.88s
# Processed sample 5: small model time = 1.40s
# Processed sample 6: small model time = 1.32s
# Processed sample 7: small model time = 2.90s
# Processed sample 8: small model time = 1.50s
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Processed sample 9: small model time = 0.79s
# Processed sample 10: small model time = 1.06s
# Processed sample 11: small model time = 1.29s
# Processed sample 12: small model time = 1.82s
# Processed sample 13: small model time = 0.69s
# Processed sample 14: small model time = 0.69s
# Processed sample 15: small model time = 3.49s
# Processed sample 16: small model time = 1.40s
# Processed sample 17: small model time = 0.58s
# Processed sample 18: small model time = 1.06s
# Processed sample 19: small model time = 0.94s
# Processed sample 20: small model time = 2.42s
# Processed sample 21: small model time = 0.80s
# Processed sample 22: small model time = 0.65s
# Processed sample 23: small model time = 0.78s
# Processed sample 24: small model time = 2.37s
# Processed sample 25: small model time = 2.75s
# Processed sample 26: small model time = 3.39s
# Processed sample 27: small model time = 2.20s
# Processed sample 28: small model time = 0.98s
# Processed sample 29: small model time = 3.30s
# Processed sample 30: small model time = 0.94s
# Processed sample 31: small model time = 1.51s
# Processed sample 32: small model time = 1.98s
# Processed sample 33: small model time = 2.65s
# Processed sample 34: small model time = 0.56s
# Processed sample 35: small model time = 1.57s
# Processed sample 36: small model time = 1.21s
# Processed sample 37: small model time = 1.73s
# Processed sample 38: small model time = 1.86s
# Processed sample 39: small model time = 0.98s
# Processed sample 40: small model time = 1.62s
# Processed sample 41: small model time = 1.85s
# Processed sample 42: small model time = 3.55s
# Processed sample 43: small model time = 0.66s
# Processed sample 44: small model time = 1.05s
# Processed sample 45: small model time = 1.32s
# Processed sample 46: small model time = 1.54s
# Processed sample 47: small model time = 2.31s
# Processed sample 48: small model time = 1.23s
# Processed sample 49: small model time = 0.98s
# Processed sample 50: small model time = 1.58s
# Processed sample 51: small model time = 1.58s
# Processed sample 52: small model time = 0.85s
# Processed sample 53: small model time = 0.91s
# Processed sample 54: small model time = 0.65s
# Processed sample 55: small model time = 0.53s
# Processed sample 56: small model time = 0.62s
# Processed sample 57: small model time = 0.55s
# Processed sample 58: small model time = 2.43s
# Processed sample 59: small model time = 3.23s
# Processed sample 60: small model time = 2.60s
# Processed sample 61: small model time = 2.51s
# Processed sample 62: small model time = 0.44s
# Processed sample 63: small model time = 1.87s
# Processed sample 64: small model time = 1.39s
# Processed sample 65: small model time = 2.64s
# Processed sample 66: small model time = 2.82s
# Processed sample 67: small model time = 2.31s
# Processed sample 68: small model time = 1.89s
# Processed sample 69: small model time = 1.08s
# Processed sample 70: small model time = 1.62s
# Processed sample 71: small model time = 1.40s
# Processed sample 72: small model time = 0.44s
# Processed sample 73: small model time = 0.44s
# Processed sample 74: small model time = 0.99s
# Processed sample 75: small model time = 0.62s
# Processed sample 76: small model time = 1.39s
# Processed sample 77: small model time = 1.30s
# Processed sample 78: small model time = 2.77s
# Processed sample 79: small model time = 3.37s
# Processed sample 80: small model time = 1.24s
# Processed sample 81: small model time = 0.65s
# Processed sample 82: small model time = 2.77s
# Processed sample 83: small model time = 0.78s
# Processed sample 84: small model time = 0.42s
# Processed sample 85: small model time = 0.76s
# Processed sample 86: small model time = 1.41s
# Processed sample 87: small model time = 1.33s
# Processed sample 88: small model time = 0.82s
# Processed sample 89: small model time = 1.05s
# Processed sample 90: small model time = 0.91s
# Processed sample 91: small model time = 0.61s
# Processed sample 92: small model time = 0.49s
# Processed sample 93: small model time = 2.19s
# Processed sample 94: small model time = 0.88s
# Processed sample 95: small model time = 1.28s
# Processed sample 96: small model time = 0.42s
# Processed sample 97: small model time = 0.42s
# Processed sample 98: small model time = 2.02s
# Processed sample 99: small model time = 0.43s
# Processed sample 100: small model time = 0.65s
# Processed sample 101: small model time = 1.74s
# Processed sample 102: small model time = 0.57s
# Processed sample 103: small model time = 0.56s
# Processed sample 104: small model time = 0.57s
# Processed sample 105: small model time = 0.93s
# Processed sample 106: small model time = 1.46s
# Processed sample 107: small model time = 0.44s
# Processed sample 108: small model time = 0.54s
# Processed sample 109: small model time = 0.43s
# Processed sample 110: small model time = 1.76s
# Processed sample 111: small model time = 1.00s
# Processed sample 112: small model time = 0.43s
# Processed sample 113: small model time = 1.74s
# Processed sample 114: small model time = 0.65s
# Processed sample 115: small model time = 1.00s
# Processed sample 116: small model time = 0.55s
# Processed sample 117: small model time = 0.54s
# Processed sample 118: small model time = 1.68s
# Processed sample 119: small model time = 1.07s
# Processed sample 120: small model time = 1.43s
# Processed sample 121: small model time = 0.49s
# Processed sample 122: small model time = 1.21s
# Processed sample 123: small model time = 0.65s
# Processed sample 124: small model time = 0.42s
# Processed sample 125: small model time = 0.96s
# Processed sample 126: small model time = 1.09s
# Processed sample 127: small model time = 0.86s
# Processed sample 128: small model time = 0.62s
# Processed sample 129: small model time = 1.94s
# Processed sample 130: small model time = 0.80s
# Processed sample 131: small model time = 1.38s
# Processed sample 132: small model time = 0.69s
# Processed sample 133: small model time = 3.39s
# Processed sample 134: small model time = 1.12s
# Processed sample 135: small model time = 1.50s
# Processed sample 136: small model time = 0.65s
# Processed sample 137: small model time = 0.73s
# Processed sample 138: small model time = 0.40s
# Processed sample 139: small model time = 0.73s
# Processed sample 140: small model time = 0.41s
# Processed sample 141: small model time = 1.10s
# Processed sample 142: small model time = 0.95s
# Processed sample 143: small model time = 1.87s
# Processed sample 144: small model time = 1.22s
# Processed sample 145: small model time = 0.97s
# Processed sample 146: small model time = 0.78s
# Processed sample 147: small model time = 0.78s
# Processed sample 148: small model time = 0.86s
# Processed sample 149: small model time = 0.42s
# Processed sample 150: small model time = 0.67s
# Processed sample 151: small model time = 1.53s
# Processed sample 152: small model time = 0.75s
# Processed sample 153: small model time = 1.81s
# Processed sample 154: small model time = 3.58s
# Processed sample 155: small model time = 0.57s
# Processed sample 156: small model time = 0.89s
# Processed sample 157: small model time = 1.62s
# Processed sample 158: small model time = 1.09s
# Processed sample 159: small model time = 2.14s
# Processed sample 160: small model time = 1.90s
# Processed sample 161: small model time = 0.88s
# Processed sample 162: small model time = 0.43s
# Processed sample 163: small model time = 0.67s
# Processed sample 164: small model time = 0.43s
# Processed sample 165: small model time = 1.06s
# Processed sample 166: small model time = 1.51s
# Processed sample 167: small model time = 1.75s
# Processed sample 168: small model time = 1.25s
# Processed sample 169: small model time = 3.13s
# Processed sample 170: small model time = 1.03s
# Processed sample 171: small model time = 0.44s
# Processed sample 172: small model time = 1.38s
# Processed sample 173: small model time = 0.63s
# Processed sample 174: small model time = 0.64s
# Processed sample 175: small model time = 0.51s
# Processed sample 176: small model time = 0.55s
# Processed sample 177: small model time = 0.41s
# Processed sample 178: small model time = 1.63s
# Processed sample 179: small model time = 0.89s
# Processed sample 180: small model time = 4.86s
# Processed sample 181: small model time = 0.92s
# Processed sample 182: small model time = 1.57s
# Processed sample 183: small model time = 1.09s
# Processed sample 184: small model time = 0.41s
# Processed sample 185: small model time = 0.42s
# Processed sample 186: small model time = 1.48s
# Processed sample 187: small model time = 0.52s
# Processed sample 188: small model time = 0.42s
# Processed sample 189: small model time = 0.77s
# Processed sample 190: small model time = 0.41s
# Processed sample 191: small model time = 0.53s
# Processed sample 192: small model time = 0.41s
# Processed sample 193: small model time = 0.42s
# Processed sample 194: small model time = 0.64s
# Processed sample 195: small model time = 0.55s
# Processed sample 196: small model time = 0.83s
# Processed sample 197: small model time = 1.36s
# Processed sample 198: small model time = 1.49s
# Processed sample 199: small model time = 1.07s
# Processed sample 200: small model time = 1.07s
# Processed sample 201: small model time = 0.64s
# Processed sample 202: small model time = 1.29s
# Processed sample 203: small model time = 1.83s
# Processed sample 204: small model time = 1.09s
# Processed sample 205: small model time = 3.41s
# Processed sample 206: small model time = 3.09s
# Processed sample 207: small model time = 1.50s
# Processed sample 208: small model time = 3.05s
# Processed sample 209: small model time = 1.01s
# Processed sample 210: small model time = 2.23s
# Processed sample 211: small model time = 3.02s
# Processed sample 212: small model time = 2.11s
# Processed sample 213: small model time = 3.92s
# Processed sample 214: small model time = 1.44s
# Processed sample 215: small model time = 1.54s
# Processed sample 216: small model time = 1.76s
# Processed sample 217: small model time = 2.26s
# Processed sample 218: small model time = 1.33s
# Processed sample 219: small model time = 2.67s
# Processed sample 220: small model time = 1.35s
# Processed sample 221: small model time = 0.76s
# Processed sample 222: small model time = 0.69s
# Processed sample 223: small model time = 3.08s
# Processed sample 224: small model time = 1.14s
# Processed sample 225: small model time = 2.66s
# Processed sample 226: small model time = 0.82s
# Processed sample 227: small model time = 0.70s
# Processed sample 228: small model time = 1.21s
# Processed sample 229: small model time = 1.61s
# Processed sample 230: small model time = 1.32s
# Processed sample 231: small model time = 1.73s
# Processed sample 232: small model time = 0.51s
# Processed sample 233: small model time = 1.57s
# Processed sample 234: small model time = 1.70s
# Processed sample 235: small model time = 1.09s
# Processed sample 236: small model time = 0.75s
# Processed sample 237: small model time = 1.15s
# Processed sample 238: small model time = 2.42s
# Processed sample 239: small model time = 1.22s
# Processed sample 240: small model time = 0.51s
# Processed sample 241: small model time = 0.44s
# Processed sample 242: small model time = 0.43s
# Processed sample 243: small model time = 0.43s
# Processed sample 244: small model time = 0.89s
# Processed sample 245: small model time = 0.52s
# Processed sample 246: small model time = 3.28s
# Processed sample 247: small model time = 0.75s
# Processed sample 248: small model time = 0.53s
# Processed sample 249: small model time = 0.43s
# Processed sample 250: small model time = 0.43s
# Processed sample 251: small model time = 1.19s
# Processed sample 252: small model time = 3.10s
# Processed sample 253: small model time = 0.78s
# Processed sample 254: small model time = 0.56s
# Processed sample 255: small model time = 0.86s
# Processed sample 256: small model time = 2.72s
# Processed sample 257: small model time = 0.45s
# Processed sample 258: small model time = 0.55s
# Processed sample 259: small model time = 0.96s
# Processed sample 260: small model time = 2.40s
# Processed sample 261: small model time = 0.54s
# Processed sample 262: small model time = 0.74s
# Processed sample 263: small model time = 1.30s
# Processed sample 264: small model time = 2.12s
# Processed sample 265: small model time = 1.48s
# Processed sample 266: small model time = 0.96s
# Processed sample 267: small model time = 0.52s
# Processed sample 268: small model time = 0.42s
# Processed sample 269: small model time = 1.53s
# Processed sample 270: small model time = 1.77s
# Processed sample 271: small model time = 1.53s
# Processed sample 272: small model time = 0.50s
# Processed sample 273: small model time = 2.12s
# Processed sample 274: small model time = 2.06s
# Processed sample 275: small model time = 1.89s
# Processed sample 276: small model time = 0.93s
# Processed sample 277: small model time = 0.88s
# Processed sample 278: small model time = 0.54s
# Processed sample 279: small model time = 2.39s
# Processed sample 280: small model time = 0.56s
# Processed sample 281: small model time = 0.65s
# Processed sample 282: small model time = 2.29s
# Processed sample 283: small model time = 0.99s
# Processed sample 284: small model time = 1.31s
# Processed sample 285: small model time = 3.53s
# Processed sample 286: small model time = 0.66s
# Processed sample 287: small model time = 0.54s
# Processed sample 288: small model time = 1.99s
# Processed sample 289: small model time = 1.55s
# Processed sample 290: small model time = 0.76s
# Processed sample 291: small model time = 1.31s
# Processed sample 292: small model time = 2.15s
# Processed sample 293: small model time = 0.88s
# Processed sample 294: small model time = 0.70s
# Processed sample 295: small model time = 0.84s
# Processed sample 296: small model time = 1.14s
# Processed sample 297: small model time = 1.58s
# Processed sample 298: small model time = 0.76s
# Processed sample 299: small model time = 1.88s
# Processed sample 300: small model time = 2.84s
# Processed sample 301: small model time = 8.86s
# Processed sample 302: small model time = 3.94s
# Processed sample 303: small model time = 0.57s
# Processed sample 304: small model time = 0.54s
# Processed sample 305: small model time = 0.52s
# Processed sample 306: small model time = 2.89s
# Processed sample 307: small model time = 1.46s
# Processed sample 308: small model time = 1.30s
# Processed sample 309: small model time = 2.80s
# Processed sample 310: small model time = 3.08s
# Processed sample 311: small model time = 0.54s
# Processed sample 312: small model time = 1.30s
# Processed sample 313: small model time = 0.42s
# Processed sample 314: small model time = 0.53s
# Processed sample 315: small model time = 2.85s
# Processed sample 316: small model time = 0.80s
# Processed sample 317: small model time = 0.81s
# Processed sample 318: small model time = 6.19s
# Processed sample 319: small model time = 2.62s
# Processed sample 320: small model time = 0.68s
# Processed sample 321: small model time = 0.75s
# Processed sample 322: small model time = 0.88s
# Processed sample 323: small model time = 1.29s
# Processed sample 324: small model time = 1.20s
# Processed sample 325: small model time = 0.68s
# Processed sample 326: small model time = 3.61s
# Processed sample 327: small model time = 3.30s
# Processed sample 328: small model time = 0.88s
# Processed sample 329: small model time = 1.07s
# Processed sample 330: small model time = 1.27s
# Processed sample 331: small model time = 6.04s
# Processed sample 332: small model time = 0.55s
# Processed sample 333: small model time = 2.78s
# Processed sample 334: small model time = 3.05s
# Processed sample 335: small model time = 1.69s
# Processed sample 336: small model time = 1.08s
# Processed sample 337: small model time = 2.04s
# Processed sample 338: small model time = 3.36s
# Processed sample 339: small model time = 1.31s
# Processed sample 340: small model time = 1.07s
# Processed sample 341: small model time = 0.76s
# Processed sample 342: small model time = 0.45s
# Processed sample 343: small model time = 1.08s
# Processed sample 344: small model time = 4.93s
# Processed sample 345: small model time = 3.68s
# Processed sample 346: small model time = 0.56s
# Processed sample 347: small model time = 2.57s
# Processed sample 348: small model time = 3.77s
# Processed sample 349: small model time = 2.43s
# Processed sample 350: small model time = 0.58s
# Processed sample 351: small model time = 1.29s
# Processed sample 352: small model time = 3.70s
# Processed sample 353: small model time = 1.68s
# Processed sample 354: small model time = 1.46s
# Processed sample 355: small model time = 1.10s
# Processed sample 356: small model time = 1.55s
# Processed sample 357: small model time = 1.53s
# Processed sample 358: small model time = 0.43s
# Processed sample 359: small model time = 7.54s
# Processed sample 360: small model time = 0.99s
# Processed sample 361: small model time = 0.54s
# Processed sample 362: small model time = 0.96s
# Processed sample 363: small model time = 1.83s
# Processed sample 364: small model time = 1.31s
# Processed sample 365: small model time = 0.74s
# Processed sample 366: small model time = 5.93s
# Processed sample 367: small model time = 0.68s
# Processed sample 368: small model time = 1.32s
# Processed sample 369: small model time = 0.77s
# Processed sample 370: small model time = 0.98s
# Processed sample 371: small model time = 2.71s
# Processed sample 372: small model time = 1.35s
# Processed sample 373: small model time = 7.64s
# Processed sample 374: small model time = 0.89s
# Processed sample 375: small model time = 0.53s
# Processed sample 376: small model time = 0.54s
# Processed sample 377: small model time = 0.73s
# Processed sample 378: small model time = 0.62s
# Processed sample 379: small model time = 1.64s
# Processed sample 380: small model time = 1.28s
# Processed sample 381: small model time = 1.88s
# Processed sample 382: small model time = 2.22s
# Processed sample 383: small model time = 7.61s
# Processed sample 384: small model time = 1.71s
# Processed sample 385: small model time = 1.74s
# Processed sample 386: small model time = 0.70s
# Processed sample 387: small model time = 0.93s
# Processed sample 388: small model time = 4.92s
# Processed sample 389: small model time = 0.56s
# Processed sample 390: small model time = 0.53s
# Processed sample 391: small model time = 1.08s
# Processed sample 392: small model time = 0.52s
# Processed sample 393: small model time = 0.74s
# Processed sample 394: small model time = 2.45s
# Processed sample 395: small model time = 0.65s
# Processed sample 396: small model time = 5.90s
# Processed sample 397: small model time = 0.55s
# Processed sample 398: small model time = 0.43s
# Processed sample 399: small model time = 1.55s
# Processed sample 400: small model time = 0.41s
# Processed sample 401: small model time = 0.62s
# Processed sample 402: small model time = 0.52s
# Processed sample 403: small model time = 0.89s
# Processed sample 404: small model time = 0.98s
# Processed sample 405: small model time = 7.76s
# Processed sample 406: small model time = 1.55s
# Processed sample 407: small model time = 2.68s
# Processed sample 408: small model time = 0.73s
# Processed sample 409: small model time = 0.54s
# Processed sample 410: small model time = 0.53s
# Processed sample 411: small model time = 0.43s
# Processed sample 412: small model time = 1.61s
# Processed sample 413: small model time = 0.79s
# Processed sample 414: small model time = 1.10s
# Processed sample 415: small model time = 2.81s
# Processed sample 416: small model time = 0.89s
# Processed sample 417: small model time = 0.75s
# Processed sample 418: small model time = 0.53s
# Processed sample 419: small model time = 0.52s
# Processed sample 420: small model time = 0.75s
# Processed sample 421: small model time = 0.84s
# Processed sample 422: small model time = 3.23s
# Processed sample 423: small model time = 5.29s
# Processed sample 424: small model time = 7.94s
# Processed sample 425: small model time = 2.23s
# Processed sample 426: small model time = 2.35s
# Processed sample 427: small model time = 0.77s
# Processed sample 428: small model time = 0.77s
# Processed sample 429: small model time = 0.58s
# Processed sample 430: small model time = 1.41s
# Processed sample 431: small model time = 3.02s
# Processed sample 432: small model time = 1.11s
# Processed sample 433: small model time = 0.80s
# Processed sample 434: small model time = 2.41s
# Processed sample 435: small model time = 0.77s
# Processed sample 436: small model time = 0.91s
# Processed sample 437: small model time = 1.75s
# Processed sample 438: small model time = 1.85s
# Processed sample 439: small model time = 3.43s
# Processed sample 440: small model time = 0.67s
# Processed sample 441: small model time = 1.31s
# Processed sample 442: small model time = 1.33s
# Processed sample 443: small model time = 0.41s
# Processed sample 444: small model time = 0.96s
# Processed sample 445: small model time = 1.08s
# Processed sample 446: small model time = 0.42s
# Processed sample 447: small model time = 1.23s
# Processed sample 448: small model time = 1.13s
# Processed sample 449: small model time = 0.75s
# Processed sample 450: small model time = 1.47s
# Processed sample 451: small model time = 0.53s
# Processed sample 452: small model time = 1.09s
# Processed sample 453: small model time = 1.94s
# Processed sample 454: small model time = 1.51s
# Processed sample 455: small model time = 0.64s
# Processed sample 456: small model time = 0.79s
# Processed sample 457: small model time = 2.05s
# Processed sample 458: small model time = 0.43s
# Processed sample 459: small model time = 1.18s
# Processed sample 460: small model time = 0.97s
# Processed sample 461: small model time = 0.93s
# Processed sample 462: small model time = 0.65s
# Processed sample 463: small model time = 0.94s
# Processed sample 464: small model time = 0.86s
# Processed sample 465: small model time = 1.62s
# Processed sample 466: small model time = 2.43s
# Processed sample 467: small model time = 2.85s
# Processed sample 468: small model time = 1.09s
# Processed sample 469: small model time = 1.23s
# Processed sample 470: small model time = 3.13s
# Processed sample 471: small model time = 1.16s
# Processed sample 472: small model time = 1.90s
# Processed sample 473: small model time = 0.90s
# Processed sample 474: small model time = 0.40s
# Processed sample 475: small model time = 1.09s
# Processed sample 476: small model time = 1.26s
# Processed sample 477: small model time = 1.55s
# Processed sample 478: small model time = 0.63s
# Processed sample 479: small model time = 1.30s
# Processed sample 480: small model time = 2.31s
# Processed sample 481: small model time = 1.97s
# Processed sample 482: small model time = 1.67s
# Processed sample 483: small model time = 0.85s
# Processed sample 484: small model time = 1.77s
# Processed sample 485: small model time = 0.64s
# Processed sample 486: small model time = 4.18s
# Processed sample 487: small model time = 1.50s
# Processed sample 488: small model time = 4.55s
# Processed sample 489: small model time = 0.67s
# Processed sample 490: small model time = 0.65s
# Processed sample 491: small model time = 0.98s
# Processed sample 492: small model time = 2.16s
# Processed sample 493: small model time = 1.85s
# Processed sample 494: small model time = 1.29s
# Processed sample 495: small model time = 3.33s
# Processed sample 496: small model time = 1.74s
# Processed sample 497: small model time = 0.64s
# Processed sample 498: small model time = 0.95s
# Processed sample 499: small model time = 0.98s
# Processed sample 500: small model time = 0.42s
# Processed sample 501: small model time = 0.52s
# Processed sample 502: small model time = 1.06s
# Processed sample 503: small model time = 0.75s
# Processed sample 504: small model time = 0.86s
# Processed sample 505: small model time = 1.41s
# Processed sample 506: small model time = 2.72s
# Processed sample 507: small model time = 0.72s
# Processed sample 508: small model time = 3.49s
# Processed sample 509: small model time = 1.31s
# Processed sample 510: small model time = 2.33s
# Processed sample 511: small model time = 0.88s
# Processed sample 512: small model time = 0.56s
# Processed sample 513: small model time = 1.21s
# Processed sample 514: small model time = 1.11s
# Processed sample 515: small model time = 0.63s
# Processed sample 516: small model time = 0.53s
# Processed sample 517: small model time = 4.79s
# Processed sample 518: small model time = 0.78s
# Processed sample 519: small model time = 0.54s
# Processed sample 520: small model time = 0.64s
# Processed sample 521: small model time = 2.21s
# Processed sample 522: small model time = 2.69s
# Processed sample 523: small model time = 0.99s
# Processed sample 524: small model time = 1.30s
# Processed sample 525: small model time = 2.01s
# Processed sample 526: small model time = 2.06s
# Processed sample 527: small model time = 1.14s
# Processed sample 528: small model time = 2.11s
# Processed sample 529: small model time = 1.02s
# Processed sample 530: small model time = 1.18s
# Processed sample 531: small model time = 0.96s
# Processed sample 532: small model time = 2.31s
# Processed sample 533: small model time = 1.66s
# Processed sample 534: small model time = 3.09s
# Processed sample 535: small model time = 0.60s
# Processed sample 536: small model time = 0.79s
# Processed sample 537: small model time = 0.52s
# Processed sample 538: small model time = 3.54s
# Processed sample 539: small model time = 0.90s
# Processed sample 540: small model time = 2.12s
# Processed sample 541: small model time = 0.98s
# Processed sample 542: small model time = 0.41s
# Processed sample 543: small model time = 0.42s
# Processed sample 544: small model time = 1.64s
# Processed sample 545: small model time = 0.54s
# Processed sample 546: small model time = 1.89s
# Processed sample 547: small model time = 2.64s
# Processed sample 548: small model time = 0.45s
# Processed sample 549: small model time = 3.43s
# Processed sample 550: small model time = 0.88s
# Processed sample 551: small model time = 0.85s
# Processed sample 552: small model time = 1.75s
# Processed sample 553: small model time = 1.01s
# Processed sample 554: small model time = 1.42s
# Processed sample 555: small model time = 2.25s
# Processed sample 556: small model time = 0.96s
# Processed sample 557: small model time = 1.07s
# Processed sample 558: small model time = 2.23s
# Processed sample 559: small model time = 0.45s
# Processed sample 560: small model time = 2.80s
# Processed sample 561: small model time = 0.54s
# Processed sample 562: small model time = 2.62s
# Processed sample 563: small model time = 3.05s
# Processed sample 564: small model time = 2.32s
# Processed sample 565: small model time = 1.58s
# Processed sample 566: small model time = 2.24s
# Processed sample 567: small model time = 3.51s
# Processed sample 568: small model time = 3.32s
# Processed sample 569: small model time = 1.20s
# Processed sample 570: small model time = 3.52s
# Processed sample 571: small model time = 0.87s
# Processed sample 572: small model time = 2.11s
# Processed sample 573: small model time = 0.66s
# Processed sample 574: small model time = 1.31s
# Processed sample 575: small model time = 2.19s
# Processed sample 576: small model time = 0.76s
# Processed sample 577: small model time = 0.76s
# Processed sample 578: small model time = 1.44s
# Processed sample 579: small model time = 0.67s
# Processed sample 580: small model time = 2.02s
# Processed sample 581: small model time = 0.98s
# Processed sample 582: small model time = 0.43s
# Processed sample 583: small model time = 1.10s
# Processed sample 584: small model time = 0.84s
# Processed sample 585: small model time = 0.41s
# Processed sample 586: small model time = 2.22s
# Processed sample 587: small model time = 3.04s
# Processed sample 588: small model time = 2.28s
# Processed sample 589: small model time = 0.78s
# Processed sample 590: small model time = 2.89s
# Processed sample 591: small model time = 1.21s
# Processed sample 592: small model time = 3.37s
# Processed sample 593: small model time = 2.10s
# Processed sample 594: small model time = 2.50s
# Processed sample 595: small model time = 1.15s
# Processed sample 596: small model time = 2.70s
# Processed sample 597: small model time = 0.77s
# Processed sample 598: small model time = 0.87s
# Processed sample 599: small model time = 1.53s
# Processed sample 600: small model time = 2.16s
# Processed sample 601: small model time = 0.53s
# Processed sample 602: small model time = 1.71s
# Processed sample 603: small model time = 3.67s
# Processed sample 604: small model time = 1.22s
# Processed sample 605: small model time = 0.63s
# Processed sample 606: small model time = 1.43s
# Processed sample 607: small model time = 0.73s
# Processed sample 608: small model time = 0.93s
# Processed sample 609: small model time = 1.78s
# Processed sample 610: small model time = 1.58s
# Processed sample 611: small model time = 2.63s
# Processed sample 612: small model time = 0.93s
# Processed sample 613: small model time = 0.78s
# Processed sample 614: small model time = 1.36s
# Processed sample 615: small model time = 0.77s
# Processed sample 616: small model time = 0.76s
# Processed sample 617: small model time = 0.54s
# Processed sample 618: small model time = 0.53s
# Processed sample 619: small model time = 1.84s
# Processed sample 620: small model time = 1.20s
# Processed sample 621: small model time = 0.94s
# Processed sample 622: small model time = 1.78s
# Processed sample 623: small model time = 0.93s
# Processed sample 624: small model time = 1.24s
# Processed sample 625: small model time = 2.40s
# Processed sample 626: small model time = 1.42s
# Processed sample 627: small model time = 1.39s
# Processed sample 628: small model time = 2.86s
# Processed sample 629: small model time = 1.51s
# Processed sample 630: small model time = 1.20s
# Processed sample 631: small model time = 1.33s
# Processed sample 632: small model time = 2.93s
# Processed sample 633: small model time = 2.95s
# Processed sample 634: small model time = 1.50s
# Processed sample 635: small model time = 0.54s
# Processed sample 636: small model time = 1.27s
# Processed sample 637: small model time = 0.63s
# Processed sample 638: small model time = 0.53s
# Processed sample 639: small model time = 0.64s
# Processed sample 640: small model time = 1.64s
# Processed sample 641: small model time = 1.12s
# Processed sample 642: small model time = 2.27s
# Processed sample 643: small model time = 3.80s
# Processed sample 644: small model time = 2.24s
# Processed sample 645: small model time = 2.90s
# Processed sample 646: small model time = 1.34s
# Processed sample 647: small model time = 0.65s
# Processed sample 648: small model time = 1.15s
# Processed sample 649: small model time = 0.82s
# Processed sample 650: small model time = 1.31s
# Processed sample 651: small model time = 2.24s
# Processed sample 652: small model time = 2.90s
# Processed sample 653: small model time = 0.91s
# Processed sample 654: small model time = 0.86s
# Processed sample 655: small model time = 0.41s
# Processed sample 656: small model time = 0.53s
# Processed sample 657: small model time = 0.85s
# Processed sample 658: small model time = 0.73s
# Processed sample 659: small model time = 0.67s
# Processed sample 660: small model time = 0.53s
# Processed sample 661: small model time = 1.14s
# Processed sample 662: small model time = 0.67s
# Processed sample 663: small model time = 2.36s
# Processed sample 664: small model time = 0.68s
# Processed sample 665: small model time = 2.04s
# Processed sample 666: small model time = 0.69s
# Processed sample 667: small model time = 0.87s
# Processed sample 668: small model time = 0.63s
# Processed sample 669: small model time = 0.42s
# Processed sample 670: small model time = 0.63s
# Processed sample 671: small model time = 1.58s
# Processed sample 672: small model time = 1.26s
# Processed sample 673: small model time = 0.42s
# Processed sample 674: small model time = 1.65s
# Processed sample 675: small model time = 0.81s
# Processed sample 676: small model time = 0.57s
# Processed sample 677: small model time = 2.81s
# Processed sample 678: small model time = 1.33s
# Processed sample 679: small model time = 3.12s
# Processed sample 680: small model time = 3.85s
# Processed sample 681: small model time = 1.30s
# Processed sample 682: small model time = 0.97s
# Processed sample 683: small model time = 1.22s
# Processed sample 684: small model time = 1.22s
# Processed sample 685: small model time = 1.17s
# Processed sample 686: small model time = 1.50s
# Processed sample 687: small model time = 0.52s
# Processed sample 688: small model time = 0.44s
# Processed sample 689: small model time = 0.85s
# Processed sample 690: small model time = 3.02s
# Processed sample 691: small model time = 0.56s
# Processed sample 692: small model time = 1.30s
# Processed sample 693: small model time = 1.60s
# Processed sample 694: small model time = 1.08s
# Processed sample 695: small model time = 4.18s
# Processed sample 696: small model time = 2.09s
# Processed sample 697: small model time = 1.99s
# Processed sample 698: small model time = 0.76s
# Processed sample 699: small model time = 0.96s
# Processed sample 700: small model time = 0.63s
# Processed sample 701: small model time = 1.70s
# Processed sample 702: small model time = 1.69s
# Processed sample 703: small model time = 0.75s
# Processed sample 704: small model time = 1.84s
# Processed sample 705: small model time = 1.19s
# Processed sample 706: small model time = 0.72s
# Processed sample 707: small model time = 0.44s
# Processed sample 708: small model time = 2.18s
# Processed sample 709: small model time = 0.45s
# Processed sample 710: small model time = 0.86s
# Processed sample 711: small model time = 0.43s
# Processed sample 712: small model time = 2.03s
# Processed sample 713: small model time = 3.33s
# Processed sample 714: small model time = 0.64s
# Processed sample 715: small model time = 2.68s
# Processed sample 716: small model time = 0.66s
# Processed sample 717: small model time = 3.35s
# Processed sample 718: small model time = 0.44s
# Processed sample 719: small model time = 3.26s
# Processed sample 720: small model time = 1.61s
# Processed sample 721: small model time = 2.71s
# Processed sample 722: small model time = 0.60s
# Processed sample 723: small model time = 0.93s
# Processed sample 724: small model time = 0.64s
# Processed sample 725: small model time = 1.93s
# Processed sample 726: small model time = 0.97s
# Processed sample 727: small model time = 2.47s
# Processed sample 728: small model time = 1.35s
# Processed sample 729: small model time = 1.16s
# Processed sample 730: small model time = 1.07s
# Processed sample 731: small model time = 2.84s
# Processed sample 732: small model time = 1.18s
# Processed sample 733: small model time = 0.76s
# Processed sample 734: small model time = 0.65s
# Processed sample 735: small model time = 1.17s
# Processed sample 736: small model time = 0.96s
# Processed sample 737: small model time = 1.28s
# Processed sample 738: small model time = 1.41s
# Processed sample 739: small model time = 0.84s
# Processed sample 740: small model time = 1.37s
# Processed sample 741: small model time = 1.64s
# Processed sample 742: small model time = 0.80s
# Processed sample 743: small model time = 2.37s
# Processed sample 744: small model time = 1.54s
# Processed sample 745: small model time = 1.64s
# Processed sample 746: small model time = 1.08s
# Processed sample 747: small model time = 0.94s
# Processed sample 748: small model time = 0.64s
# Processed sample 749: small model time = 0.51s
# Processed sample 750: small model time = 1.67s
# Processed sample 751: small model time = 1.05s
# Processed sample 752: small model time = 0.51s
# Processed sample 753: small model time = 6.22s
# Processed sample 754: small model time = 0.86s
# Processed sample 755: small model time = 0.86s
# Processed sample 756: small model time = 1.76s
# Processed sample 757: small model time = 1.41s
# Processed sample 758: small model time = 0.64s
# Processed sample 759: small model time = 0.62s
# Processed sample 760: small model time = 0.75s
# Processed sample 761: small model time = 2.00s
# Processed sample 762: small model time = 0.58s
# Processed sample 763: small model time = 1.16s
# Processed sample 764: small model time = 2.31s
# Processed sample 765: small model time = 1.10s
# Processed sample 766: small model time = 0.53s
# Processed sample 767: small model time = 1.93s
# Processed sample 768: small model time = 2.36s
# Processed sample 769: small model time = 0.99s
# Processed sample 770: small model time = 0.63s
# Processed sample 771: small model time = 0.43s
# Processed sample 772: small model time = 2.22s
# Processed sample 773: small model time = 0.56s
# Processed sample 774: small model time = 2.24s
# Processed sample 775: small model time = 1.56s
# Processed sample 776: small model time = 0.44s
# Processed sample 777: small model time = 1.29s
# Processed sample 778: small model time = 2.49s
# Processed sample 779: small model time = 0.44s
# Processed sample 780: small model time = 1.28s
# Processed sample 781: small model time = 0.43s
# Processed sample 782: small model time = 2.05s
# Processed sample 783: small model time = 0.43s
# Processed sample 784: small model time = 0.58s
# Processed sample 785: small model time = 0.69s
# Processed sample 786: small model time = 0.54s
# Processed sample 787: small model time = 2.73s
# Processed sample 788: small model time = 0.53s
# Processed sample 789: small model time = 0.65s
# Processed sample 790: small model time = 1.64s
# Processed sample 791: small model time = 0.61s
# Processed sample 792: small model time = 1.62s
# Processed sample 793: small model time = 0.41s
# Processed sample 794: small model time = 1.63s
# Processed sample 795: small model time = 2.17s
# Processed sample 796: small model time = 0.49s
# Processed sample 797: small model time = 1.42s
# Processed sample 798: small model time = 1.88s
# Processed sample 799: small model time = 0.49s
# Processed sample 800: small model time = 1.91s
# Processed sample 801: small model time = 0.75s
# Processed sample 802: small model time = 0.41s
# Processed sample 803: small model time = 1.06s
# Processed sample 804: small model time = 1.99s
# Processed sample 805: small model time = 0.64s
# Processed sample 806: small model time = 1.07s
# Processed sample 807: small model time = 2.62s
# Processed sample 808: small model time = 0.57s
# Processed sample 809: small model time = 2.67s
# Processed sample 810: small model time = 0.92s
# Processed sample 811: small model time = 1.87s
# Processed sample 812: small model time = 1.07s
# Processed sample 813: small model time = 1.71s
# Processed sample 814: small model time = 1.72s
# Processed sample 815: small model time = 2.07s
# Processed sample 816: small model time = 0.44s
# Processed sample 817: small model time = 0.59s
# Processed sample 818: small model time = 1.88s
# Processed sample 819: small model time = 0.93s
# Processed sample 820: small model time = 0.84s
# Processed sample 821: small model time = 1.08s
# Processed sample 822: small model time = 2.20s
# Processed sample 823: small model time = 1.12s
# Processed sample 824: small model time = 0.75s
# Processed sample 825: small model time = 0.42s
# Processed sample 826: small model time = 3.81s
# Processed sample 827: small model time = 4.64s
# Processed sample 828: small model time = 0.77s
# Processed sample 829: small model time = 0.64s
# Processed sample 830: small model time = 0.52s
# Processed sample 831: small model time = 0.77s
# Processed sample 832: small model time = 2.34s
# Processed sample 833: small model time = 0.44s
# Processed sample 834: small model time = 1.30s
# Processed sample 835: small model time = 2.65s
# Processed sample 836: small model time = 4.04s
# Processed sample 837: small model time = 0.54s
# Processed sample 838: small model time = 1.10s
# Processed sample 839: small model time = 1.57s
# Processed sample 840: small model time = 0.73s
# Processed sample 841: small model time = 0.53s
# Processed sample 842: small model time = 0.90s
# Processed sample 843: small model time = 0.41s
# Processed sample 844: small model time = 1.53s
# Processed sample 845: small model time = 0.42s
# Processed sample 846: small model time = 0.42s
# Processed sample 847: small model time = 0.41s
# Processed sample 848: small model time = 0.41s
# Processed sample 849: small model time = 0.50s
# Processed sample 850: small model time = 0.53s
# Processed sample 851: small model time = 1.79s
# Processed sample 852: small model time = 2.25s
# Processed sample 853: small model time = 0.45s
# Processed sample 854: small model time = 1.29s
# Processed sample 855: small model time = 1.76s
# Processed sample 856: small model time = 1.53s
# Processed sample 857: small model time = 2.36s
# Processed sample 858: small model time = 1.30s
# Processed sample 859: small model time = 2.74s
# Processed sample 860: small model time = 1.27s
# Processed sample 861: small model time = 2.10s
# Processed sample 862: small model time = 3.10s
# Processed sample 863: small model time = 0.89s
# Processed sample 864: small model time = 3.05s
# Processed sample 865: small model time = 3.95s
# Processed sample 866: small model time = 1.94s
# Processed sample 867: small model time = 2.11s
# Processed sample 868: small model time = 2.10s
# Processed sample 869: small model time = 4.01s
# Processed sample 870: small model time = 0.44s
# Processed sample 871: small model time = 2.10s
# Processed sample 872: small model time = 0.96s
# Processed sample 873: small model time = 2.45s
# Processed sample 874: small model time = 2.27s
# Processed sample 875: small model time = 1.33s
# Processed sample 876: small model time = 2.13s
# Processed sample 877: small model time = 1.37s
# Processed sample 878: small model time = 0.74s
# Processed sample 879: small model time = 1.45s
# Processed sample 880: small model time = 1.29s
# Processed sample 881: small model time = 1.07s
# Processed sample 882: small model time = 1.23s
# Processed sample 883: small model time = 1.67s
# Processed sample 884: small model time = 1.63s
# Processed sample 885: small model time = 2.66s
# Processed sample 886: small model time = 2.22s
# Processed sample 887: small model time = 1.95s
# Processed sample 888: small model time = 2.14s
# Processed sample 889: small model time = 3.15s
# Processed sample 890: small model time = 0.56s
# Processed sample 891: small model time = 0.53s
# Processed sample 892: small model time = 1.76s
# Processed sample 893: small model time = 3.37s
# Processed sample 894: small model time = 1.45s
# Processed sample 895: small model time = 0.89s
# Processed sample 896: small model time = 0.84s
# Processed sample 897: small model time = 1.53s
# Processed sample 898: small model time = 1.23s
# Processed sample 899: small model time = 1.93s
# Processed sample 900: small model time = 0.41s
# Processed sample 901: small model time = 0.98s
# Processed sample 902: small model time = 1.47s
# Processed sample 903: small model time = 1.58s
# Processed sample 904: small model time = 0.54s
# Processed sample 905: small model time = 0.74s
# Processed sample 906: small model time = 1.40s
# Processed sample 907: small model time = 0.54s
# Processed sample 908: small model time = 2.96s
# Processed sample 909: small model time = 1.21s
# Processed sample 910: small model time = 0.66s
# Processed sample 911: small model time = 1.61s
# Processed sample 912: small model time = 0.87s
# Processed sample 913: small model time = 1.24s
# Processed sample 914: small model time = 0.74s
# Processed sample 915: small model time = 1.57s
# Processed sample 916: small model time = 1.50s
# Processed sample 917: small model time = 1.06s
# Processed sample 918: small model time = 2.81s
# Processed sample 919: small model time = 1.55s
# Processed sample 920: small model time = 0.45s
# Processed sample 921: small model time = 0.68s
# Processed sample 922: small model time = 2.16s
# Processed sample 923: small model time = 1.83s
# Processed sample 924: small model time = 0.86s
# Processed sample 925: small model time = 0.75s
# Processed sample 926: small model time = 1.31s
# Processed sample 927: small model time = 1.93s
# Processed sample 928: small model time = 1.27s
# Processed sample 929: small model time = 2.60s
# Processed sample 930: small model time = 1.10s
# Processed sample 931: small model time = 0.87s
# Processed sample 932: small model time = 0.64s
# Processed sample 933: small model time = 2.09s
# Processed sample 934: small model time = 3.20s
# Processed sample 935: small model time = 0.66s
# Processed sample 936: small model time = 0.67s
# Processed sample 937: small model time = 1.45s
# Processed sample 938: small model time = 0.84s
# Processed sample 939: small model time = 1.56s
# Processed sample 940: small model time = 0.69s
# Processed sample 941: small model time = 1.32s
# Processed sample 942: small model time = 1.31s
# Processed sample 943: small model time = 2.59s
# Processed sample 944: small model time = 0.46s
# Processed sample 945: small model time = 0.54s
# Processed sample 946: small model time = 3.08s
# Processed sample 947: small model time = 0.44s
# Processed sample 948: small model time = 0.87s
# Processed sample 949: small model time = 0.54s
# Processed sample 950: small model time = 1.87s
# Processed sample 951: small model time = 2.13s
# Processed sample 952: small model time = 1.32s
# Processed sample 953: small model time = 2.94s
# Processed sample 954: small model time = 1.44s
# Processed sample 955: small model time = 0.77s
# Processed sample 956: small model time = 3.41s
# Processed sample 957: small model time = 0.93s
# Processed sample 958: small model time = 2.67s
# Processed sample 959: small model time = 0.80s
# Processed sample 960: small model time = 3.52s
# Processed sample 961: small model time = 0.81s
# Processed sample 962: small model time = 3.71s
# Processed sample 963: small model time = 4.59s
# Processed sample 964: small model time = 1.96s
# Processed sample 965: small model time = 0.45s
# Processed sample 966: small model time = 0.97s
# Processed sample 967: small model time = 3.72s
# Processed sample 968: small model time = 2.59s
# Processed sample 969: small model time = 3.68s
# Processed sample 970: small model time = 3.75s
# Processed sample 971: small model time = 0.98s
# Processed sample 972: small model time = 1.67s
# Processed sample 973: small model time = 1.52s
# Processed sample 974: small model time = 2.14s
# Processed sample 975: small model time = 2.60s
# Processed sample 976: small model time = 3.42s
# Processed sample 977: small model time = 0.67s
# Processed sample 978: small model time = 1.62s
# Processed sample 979: small model time = 1.69s
# Processed sample 980: small model time = 2.84s
# Processed sample 981: small model time = 3.25s
# Processed sample 982: small model time = 3.35s
# Processed sample 983: small model time = 3.46s
# Processed sample 984: small model time = 1.33s
# Processed sample 985: small model time = 0.88s
# Processed sample 986: small model time = 3.19s
# Processed sample 987: small model time = 3.44s
# Processed sample 988: small model time = 2.94s
# Processed sample 989: small model time = 0.67s
# Processed sample 990: small model time = 1.88s
# Processed sample 991: small model time = 3.47s
# Processed sample 992: small model time = 1.71s
# Processed sample 993: small model time = 2.29s
# ...
# Processed sample 2846: small model time = 4.21s
# Processed sample 2847: small model time = 0.66s
# Processed sample 2848: small model time = 0.42s
# Processed sample 2849: small model time = 8.06s
# Processed sample 2850: small model time = 1.20s
# Processed sample 2851: small model time = 0.97s
# Processed sample 2852: small model time = 0.41s
# Processed sample 2853: small model time = 0.86s
# Processed sample 2854: small model time = 3.58s
# Processed sample 2855: small model time = 9.02s
# Processed sample 2856: small model time = 2.22s
# Processed sample 2857: small model time = 0.44s
# Processed sample 2858: small model time = 0.54s
# Processed sample 2859: small model time = 2.05s
# Processed sample 2860: small model time = 3.86s
# Processed sample 2861: small model time = 0.60s
# Processed sample 2862: small model time = 0.57s
# Processed sample 2863: small model time = 0.88s
# Processed sample 2864: small model time = 0.86s
# Processed sample 2865: small model time = 0.41s
# Processed sample 2866: small model time = 1.27s
# Processed sample 2867: small model time = 1.72s
# Processed sample 2868: small model time = 0.40s
# Processed sample 2869: small model time = 1.06s
# Processed sample 2870: small model time = 0.73s
# Processed sample 2871: small model time = 0.52s
# Processed sample 2872: small model time = 3.16s
# Processed sample 2873: small model time = 1.52s
# Processed sample 2874: small model time = 2.26s
# Processed sample 2875: small model time = 1.42s
# Processed sample 2876: small model time = 1.20s
# Processed sample 2877: small model time = 0.85s
# Processed sample 2878: small model time = 8.46s
# Processed sample 2879: small model time = 0.49s
# Processed sample 2880: small model time = 5.08s
# Processed sample 2881: small model time = 0.44s
# Processed sample 2882: small model time = 1.37s
# Processed sample 2883: small model time = 0.62s
# Processed sample 2884: small model time = 0.75s
# Processed sample 2885: small model time = 0.51s
# Processed sample 2886: small model time = 0.76s
# Processed sample 2887: small model time = 0.83s
# Processed sample 2888: small model time = 0.67s
# Processed sample 2889: small model time = 1.02s
# Processed sample 2890: small model time = 1.22s
# Processed sample 2891: small model time = 1.26s
# Processed sample 2892: small model time = 1.81s
# Processed sample 2893: small model time = 1.04s
# Processed sample 2894: small model time = 2.77s
# Processed sample 2895: small model time = 0.98s
# Processed sample 2896: small model time = 0.53s
# Processed sample 2897: small model time = 0.93s
# Processed sample 2898: small model time = 1.35s
# Processed sample 2899: small model time = 1.25s
# Processed sample 2900: small model time = 2.60s
# Processed sample 2901: small model time = 1.19s
# Processed sample 2902: small model time = 1.95s
# Processed sample 2903: small model time = 2.65s
# Processed sample 2904: small model time = 1.33s
# Processed sample 2905: small model time = 0.52s
# Processed sample 2906: small model time = 3.03s
# Processed sample 2907: small model time = 1.62s
# Processed sample 2908: small model time = 0.81s
# Processed sample 2909: small model time = 1.08s
# Processed sample 2910: small model time = 0.52s
# Processed sample 2911: small model time = 2.18s
# Processed sample 2912: small model time = 0.87s
# Processed sample 2913: small model time = 1.37s
# Processed sample 2914: small model time = 1.42s
# Processed sample 2915: small model time = 1.42s
# Processed sample 2916: small model time = 2.44s
# Processed sample 2917: small model time = 0.78s
# Processed sample 2918: small model time = 3.39s
# Processed sample 2919: small model time = 1.63s
# Processed sample 2920: small model time = 1.92s
# Processed sample 2921: small model time = 0.75s
# Processed sample 2922: small model time = 0.92s
# Processed sample 2923: small model time = 1.29s
# Processed sample 2924: small model time = 2.63s
# Processed sample 2925: small model time = 0.74s
# Processed sample 2926: small model time = 0.77s
# Processed sample 2927: small model time = 0.62s
# Processed sample 2928: small model time = 1.87s
# Processed sample 2929: small model time = 1.26s
# Processed sample 2930: small model time = 1.41s
# Processed sample 2931: small model time = 2.85s
# Processed sample 2932: small model time = 0.76s
# Processed sample 2933: small model time = 0.52s
# Processed sample 2934: small model time = 0.86s
# Processed sample 2935: small model time = 0.52s
# Processed sample 2936: small model time = 0.54s
# Processed sample 2937: small model time = 0.66s
# Processed sample 2938: small model time = 0.69s
# Processed sample 2939: small model time = 1.74s
# Processed sample 2940: small model time = 0.53s
# Processed sample 2941: small model time = 0.87s
# Processed sample 2942: small model time = 1.28s
# Processed sample 2943: small model time = 1.37s
# Processed sample 2944: small model time = 0.96s
# Processed sample 2945: small model time = 0.97s
# Processed sample 2946: small model time = 1.91s
# Processed sample 2947: small model time = 2.26s
# Processed sample 2948: small model time = 2.88s
# Processed sample 2949: small model time = 2.60s
# Processed sample 2950: small model time = 2.55s
# Processed sample 2951: small model time = 2.66s
# Processed sample 2952: small model time = 0.75s
# Processed sample 2953: small model time = 1.50s
# Processed sample 2954: small model time = 0.52s
# Processed sample 2955: small model time = 0.47s
# Processed sample 2956: small model time = 1.25s
# Processed sample 2957: small model time = 2.68s
# Processed sample 2958: small model time = 1.11s
# Processed sample 2959: small model time = 1.40s
# Processed sample 2960: small model time = 1.04s
# Processed sample 2961: small model time = 1.05s
# Processed sample 2962: small model time = 0.85s
# Processed sample 2963: small model time = 0.95s
# Processed sample 2964: small model time = 2.26s
# Processed sample 2965: small model time = 0.83s
# Processed sample 2966: small model time = 3.59s
# Processed sample 2967: small model time = 2.92s
# Processed sample 2968: small model time = 1.07s
# Processed sample 2969: small model time = 0.54s
# Processed sample 2970: small model time = 1.08s
# Processed sample 2971: small model time = 0.74s
# Processed sample 2972: small model time = 1.59s
# Processed sample 2973: small model time = 0.85s
# Processed sample 2974: small model time = 0.86s
# Processed sample 2975: small model time = 3.97s
# Processed sample 2976: small model time = 1.90s
# Processed sample 2977: small model time = 0.95s
# Processed sample 2978: small model time = 0.84s
# Processed sample 2979: small model time = 1.33s
# Processed sample 2980: small model time = 1.60s
# Processed sample 2981: small model time = 1.50s
# Processed sample 2982: small model time = 1.50s
# Processed sample 2983: small model time = 0.72s
# Processed sample 2984: small model time = 3.01s
# Processed sample 2985: small model time = 0.65s
# Processed sample 2986: small model time = 0.50s
# Processed sample 2987: small model time = 1.28s
# Processed sample 2988: small model time = 1.05s
# Processed sample 2989: small model time = 1.82s
# Processed sample 2990: small model time = 1.48s
# Processed sample 2991: small model time = 0.83s
# Processed sample 2992: small model time = 1.18s
# Processed sample 2993: small model time = 1.30s
# Processed sample 2994: small model time = 1.36s
# Processed sample 2995: small model time = 1.09s
# Processed sample 2996: small model time = 1.24s
# Processed sample 2997: small model time = 1.08s
# Processed sample 2998: small model time = 0.43s
# Processed sample 2999: small model time = 0.42s
# Processed sample 3000: small model time = 0.52s
# Processed sample 3001: small model time = 0.72s
# Processed sample 3002: small model time = 0.83s
# Processed sample 3003: small model time = 0.74s
# Processed sample 3004: small model time = 1.24s
# Processed sample 3005: small model time = 1.08s
# Processed sample 3006: small model time = 0.73s
# Processed sample 3007: small model time = 0.51s
# Processed sample 3008: small model time = 0.85s
# Processed sample 3009: small model time = 1.04s
# Processed sample 3010: small model time = 20.25s
# Processed sample 3011: small model time = 1.22s
# Processed sample 3012: small model time = 0.84s
# Processed sample 3013: small model time = 1.37s
# Processed sample 3014: small model time = 0.94s
# Processed sample 3015: small model time = 0.52s
# Processed sample 3016: small model time = 0.73s
# Processed sample 3017: small model time = 1.53s
# Processed sample 3018: small model time = 1.04s
# Processed sample 3019: small model time = 1.44s
# Processed sample 3020: small model time = 1.29s
# Processed sample 3021: small model time = 1.25s
# Processed sample 3022: small model time = 0.96s
# Processed sample 3023: small model time = 0.53s
# Processed sample 3024: small model time = 1.80s
# Processed sample 3025: small model time = 0.95s
# Processed sample 3026: small model time = 2.30s
# Processed sample 3027: small model time = 1.26s
# Processed sample 3028: small model time = 1.16s
# Processed sample 3029: small model time = 1.56s
# Processed sample 3030: small model time = 1.91s
# Processed sample 3031: small model time = 2.62s
# Processed sample 3032: small model time = 0.54s
# Processed sample 3033: small model time = 0.53s
# Processed sample 3034: small model time = 1.17s
# Processed sample 3035: small model time = 1.71s
# Processed sample 3036: small model time = 1.60s
# Processed sample 3037: small model time = 0.94s
# Processed sample 3038: small model time = 0.97s
# Processed sample 3039: small model time = 1.31s
# Processed sample 3040: small model time = 12.72s
# Processed sample 3041: small model time = 0.98s
# Processed sample 3042: small model time = 1.59s
# Processed sample 3043: small model time = 2.24s
# Processed sample 3044: small model time = 0.80s
# Processed sample 3045: small model time = 1.19s
# Processed sample 3046: small model time = 2.40s
# Processed sample 3047: small model time = 1.61s
# Processed sample 3048: small model time = 1.27s
# Processed sample 3049: small model time = 1.05s
# Processed sample 3050: small model time = 0.72s
# Processed sample 3051: small model time = 0.41s
# Processed sample 3052: small model time = 2.22s
# Processed sample 3053: small model time = 0.74s
# Processed sample 3054: small model time = 1.40s
# Processed sample 3055: small model time = 0.45s
# Processed sample 3056: small model time = 0.42s
# Processed sample 3057: small model time = 1.48s
# Processed sample 3058: small model time = 0.41s
# Processed sample 3059: small model time = 0.52s
# Processed sample 3060: small model time = 0.50s
# Processed sample 3061: small model time = 1.94s
# Processed sample 3062: small model time = 0.95s
# Processed sample 3063: small model time = 0.84s
# Processed sample 3064: small model time = 1.47s
# Processed sample 3065: small model time = 1.31s
# Processed sample 3066: small model time = 2.04s
# Processed sample 3067: small model time = 1.57s
# Processed sample 3068: small model time = 1.19s
# Processed sample 3069: small model time = 1.49s
# Processed sample 3070: small model time = 1.71s
# Processed sample 3071: small model time = 3.85s
# Processed sample 3072: small model time = 2.86s
# Processed sample 3073: small model time = 0.57s
# Processed sample 3074: small model time = 3.35s
# Processed sample 3075: small model time = 0.66s
# Processed sample 3076: small model time = 0.57s
# Processed sample 3077: small model time = 0.52s
# Processed sample 3078: small model time = 0.62s
# Processed sample 3079: small model time = 0.72s
# Processed sample 3080: small model time = 0.94s
# Processed sample 3081: small model time = 0.51s
# Processed sample 3082: small model time = 1.05s
# Processed sample 3083: small model time = 2.85s
# Processed sample 3084: small model time = 2.10s
# Processed sample 3085: small model time = 1.36s
# Processed sample 3086: small model time = 1.67s
# Processed sample 3087: small model time = 1.49s
# Processed sample 3088: small model time = 0.84s
# Processed sample 3089: small model time = 3.40s
# Processed sample 3090: small model time = 1.66s
# Processed sample 3091: small model time = 1.41s
# Processed sample 3092: small model time = 4.97s
# Processed sample 3093: small model time = 1.64s
# Processed sample 3094: small model time = 1.79s
# Processed sample 3095: small model time = 1.65s
# Processed sample 3096: small model time = 0.95s
# Processed sample 3097: small model time = 2.72s
# Processed sample 3098: small model time = 2.39s
# Processed sample 3099: small model time = 2.38s
# Processed sample 3100: small model time = 0.69s
# Processed sample 3101: small model time = 0.86s
# Processed sample 3102: small model time = 3.77s
# Processed sample 3103: small model time = 0.88s
# Processed sample 3104: small model time = 0.86s
# Processed sample 3105: small model time = 0.55s
# Processed sample 3106: small model time = 3.82s
# Processed sample 3107: small model time = 0.70s
# Processed sample 3108: small model time = 1.06s
# Processed sample 3109: small model time = 0.63s
# Processed sample 3110: small model time = 1.88s
# Processed sample 3111: small model time = 0.44s
# Processed sample 3112: small model time = 0.42s
# Processed sample 3113: small model time = 0.41s
# Processed sample 3114: small model time = 0.51s
# Processed sample 3115: small model time = 1.05s
# Processed sample 3116: small model time = 0.41s
# Processed sample 3117: small model time = 0.74s
# Processed sample 3118: small model time = 1.08s
# Processed sample 3119: small model time = 1.04s
# Processed sample 3120: small model time = 1.06s
# Processed sample 3121: small model time = 1.88s
# Processed sample 3122: small model time = 1.63s
# Processed sample 3123: small model time = 0.55s
# Processed sample 3124: small model time = 0.60s
# Processed sample 3125: small model time = 1.49s
# Processed sample 3126: small model time = 1.74s
# Processed sample 3127: small model time = 2.41s
# Processed sample 3128: small model time = 1.39s
# Processed sample 3129: small model time = 1.07s
# Processed sample 3130: small model time = 2.37s
# Processed sample 3131: small model time = 0.96s
# Processed sample 3132: small model time = 2.64s
# Processed sample 3133: small model time = 2.31s
# Processed sample 3134: small model time = 0.55s
# Processed sample 3135: small model time = 0.43s
# Processed sample 3136: small model time = 1.63s
# Processed sample 3137: small model time = 1.19s
# Processed sample 3138: small model time = 0.84s
# Processed sample 3139: small model time = 1.16s
# Processed sample 3140: small model time = 0.52s
# Processed sample 3141: small model time = 2.20s
# Processed sample 3142: small model time = 1.01s
# Processed sample 3143: small model time = 1.89s
# Processed sample 3144: small model time = 1.10s
# Processed sample 3145: small model time = 0.41s
# Processed sample 3146: small model time = 0.63s
# Processed sample 3147: small model time = 0.50s
#                                    reference  \
# 0                                    hai weh
# 1     ah makanan bagi aku macam struggle kan
# 2      makanan yang sedap kat Malaysia ni tu
# 3                                     kenapa
# 4                        dia punya dia punya
# ...                                      ...
# 3143      okey aku pun tu je la makanan yang
# 3144                   makanan kegemaran aku
# 3145                                      so
# 3146                              jumpa lagi
# 3147                                 bye bye
#
#                     whisper_small_prediction  whisper_small_process_time
# 0                                    hai weh                    3.553121
# 1     ah makanan bagi aku macam struggle kan                    1.381811
# 2      makanan yang sedap kat Malaysia ni tu                    1.314597
# 3                                     kenapa                    0.551974
# 4                        dia punya dia punya                    0.882010
# ...                                      ...                         ...
# 3143      okey aku pun tercelah makanan yang                    1.890374
# 3144                   makanan kegemaran aku                    1.101784
# 3145                                      so                    0.414639
# 3146                              sempa lagi                    0.632356
# 3147                                 bye bye                    0.502543
#
# [3148 rows x 3 columns]

# %%
df_results.to_csv("peft_evaluate_small_epoch_20.csv", index=False)

# !cp {"peft_evaluate_small_epoch_20.csv"} "/content/drive/MyDrive/"
